# %%
from financial_dataset_preprocessor import *
# Out:
# INFO:shining_pebbles:shining_pebbles package initialized

# %%
get_all_fund_names()
get_all_fund_nav()
get_all_fund_prices()
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# {'000005': 1669.17,
#  '000006': 1531.72,
#  '000012': 1381.1,
#  '000014': 1280.58,
#  '000018': 1529.09,
#  '000019': 1451.63,
#  '00001I': 1019.12,
#  '000038': 1496.95,
#  '000039': 1241.56,
#  '000040': 1199.9,
# ...

# %%
get_all_mappings_of_all_funds_by_date()
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# 펀드명
#       index                           펀드명
# 0    000005             라이프IPO일반사모투자신탁제2호
# 1    000006     라이프IPO일반사모투자신탁제2호 Class C
# 2    000012          라이프IPO전문투자형사모투자신탁제3호
# 3    000014  라이프IPO전문투자형사모투자신탁제3호 Class C
# 4    000018            라이프SPAC일반사모투자신탁제1호
# ..      ...                           ...
# 171  A00011                     한국증권금융 일임
# 172  A00012                 라이프 주식 SJ 제3호
# 173  A00013                   라이프 ESG형 7호
# 174  A00014                   라이프 ESG형 8호
# 175  A00015                TMF(라이프사회책임1호)
#
# [176 rows x 2 columns]
# 운용역
#       index  운용역
# 0    000005  남두우
# 1    000006  남두우
# 2    000012  남두우
# 3    000014  남두우
# 4    000018  남두우
# ..      ...  ...
# 171  A00011  이시우
# 172  A00012  강대권
# ...

# %%
df = get_preprocessed_menu8186_snapshot(date_ref=None).reset_index()
somethings = df.columns.tolist()
# dct = {}
something = somethings[1]
cols_to_keep =['index', something]
df = df[cols_to_keep]
# df
data = map_df_to_data(df)
# data
mapping = {datum['index']: datum[something] for datum in data}
mapping
# dct[something] = mapping
# dct
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# {'000005': '2025-02-19',
#  '000006': '2025-02-19',
#  '000012': '2025-02-19',
#  '000014': '2025-02-19',
#  '000018': '2025-02-19',
#  '000019': '2025-02-19',
#  '00001I': '2025-02-19',
#  '000038': '2025-02-19',
#  '000039': '2025-02-19',
#  '000040': '2025-02-19',
#  '000041': '2025-02-19',
#  '000042': '2025-02-19',
#  '000043': '2025-02-19',
#  '000045': '2025-02-19',
#  '000046': '2025-02-19',
#  '000048': '2025-02-19',
#  '000050': '2025-02-19',
#  '000051': '2025-02-19',
#  '000053': '2025-02-19',
#  '000054': '2025-02-19',
#  '000055': '2025-02-19',
#  '000056': '2025-02-19',
#  '000057': '2025-02-19',
#  '000058': '2025-02-19',
#  '000059': '2025-02-19',
#  '000060': '2025-02-19',
#  '000061': '2025-02-19',
# ...

# %%
get_all_mappings_of_all_funds_by_date()
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_all_mappings_of_all_funds_by_date()
#
# File ~/dev/module-financial_dataset_preprocessor/financial_dataset_preprocessor/menu8186_preprocessor/menu8186_applications.py:49, in get_all_mappings_of_all_funds_by_date(date_ref)
#      47     df = df[cols_to_keep]
#      48     data = map_df_to_data(df)
# ---> 49     mapping = {datum['index']: datum[something] for datum in data}
#      50     dct[something] = mapping
#      51 return dct
#
# ...

# %%
get_preprocessed_menu8186_snapshot().reset_index()
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
#       index          일자                           펀드명  운용역  KOSPI지수  KOSDAQ지수  \
# 0    000005  2025-02-19             라이프IPO일반사모투자신탁제2호  남두우  2671.52    778.27
# 1    000006  2025-02-19     라이프IPO일반사모투자신탁제2호 Class C  남두우  2671.52    778.27
# 2    000012  2025-02-19          라이프IPO전문투자형사모투자신탁제3호  남두우  2671.52    778.27
# 3    000014  2025-02-19  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우  2671.52    778.27
# 4    000018  2025-02-19            라이프SPAC일반사모투자신탁제1호  남두우  2671.52    778.27
# ..      ...         ...                           ...  ...      ...       ...
# 171  A00011  2025-02-19                     한국증권금융 일임  이시우  2671.52    778.27
# 172  A00012  2025-02-19                 라이프 주식 SJ 제3호  강대권  2671.52    778.27
# ...

# %%
get_all_mappings_of_all_funds_by_date()
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# /Users/juneyoungpark/dev/module-financial_dataset_preprocessor/env-preprocessor/lib/python3.11/site-packages/canonical_transformer/dataframe_utils.py:19: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   data = df.to_dict(orient='records')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_all_mappings_of_all_funds_by_date()
#
# File ~/dev/module-financial_dataset_preprocessor/financial_dataset_preprocessor/menu8186_preprocessor/menu8186_applications.py:47, in get_all_mappings_of_all_funds_by_date(date_ref)
#      45 for something in somethings:
# ...

# %%
get_mapping_something_of_fund_by_date(something='수정기준가')
get_mapping_something_of_fund_by_date(something='펀드유형')
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# {'000005': 1669.17,
#  '000006': 1531.72,
#  '000012': 1381.1,
#  '000014': 1280.58,
#  '000018': 1529.09,
#  '000019': 1451.63,
#  '00001I': 1019.12,
#  '000038': 1496.95,
#  '000039': 1241.56,
#  '000040': 1199.9,
#  '000041': 1206.21,
#  '000042': 1210.49,
#  '000043': 1064.52,
#  '000045': 1187.19,
#  '000046': 1155.32,
#  '000048': 1144.19,
#  '000050': 1159.0,
#  '000051': 1139.3,
#  '000053': 1150.3,
#  '000054': 1132.01,
#  '000055': 1131.59,
#  '000056': 1034.51,
#  '000057': 1013.07,
#  '000058': 1016.36,
#  '000059': 1017.23,
#  '000060': 1018.38,
#  '000061': 1047.27,
#  '000062': 1041.77,
#  '000063': 1023.88,
#  '000065': 1027.83,
#  '000066': 1028.32,
#  '000067': 1027.2,
#  '000068': 1009.92,
#  '000069': 1005.13,
# ...

# %%
somethings = show_all_somethings_for_data_menu8186()
dct = {something: get_mapping_something_of_fund_by_date(something=something) for something in somethings}
dct
# Out:
# Show all somethings for get_all_something_of_fund_by_date(something=...)
# ['일자', '펀드명', '운용역', 'KOSPI지수', 'KOSDAQ지수', 'KOSPI200지수', '기준가격', '기준가격: 증감', '과표기준가', '과표기준가: 증감', '해외비과세과표기준가', '해외비과세과표기준가: 증감', '비거주자과표기준가', '수정기준가', '순자산', '수탁사', '설정일', '설정좌수', '설정액', '펀드유형', '과표구분', '신탁구분', '사무수탁사', '주식비율', '채권비율', '주식순비율', '채권순비율', '지수선물순비율', '국고채3년금리', '국고채5년금리', '통안채2년금리', 'CD91', '전일대비수익률', '주간수익률(%)', '1개월수익률(%)', '3개월수익률(%)', '12개월수익률(%)', 'BM기준가', '전일대비BM수익률(%)']
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# ...

# %%
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# {'000005': '주혼',
#  '000006': '주혼',
#  '000012': '주혼',
#  '000014': '주혼',
#  '000018': '주혼',
#  '000019': '주혼',
#  '00001I': '주혼',
#  '000038': '주혼',
#  '000039': '혼합',
#  '000040': '혼합',
#  '000041': '혼합',
#  '000042': '혼합',
#  '000043': '주혼',
#  '000045': '혼합',
#  '000046': '혼합',
#  '000048': '혼합',
#  '000050': '혼합',
#  '000051': '혼합',
#  '000053': '채혼',
#  '000054': '채혼',
#  '000055': '채혼',
#  '000056': '혼합',
#  '000057': '혼합',
#  '000058': '혼합',
#  '000059': '혼합',
#  '000060': '혼합',
#  '000061': '주혼',
#  '000062': '혼합',
#  '000063': '혼합',
#  '000065': '혼합',
#  '000066': '혼합',
#  '000067': '혼합',
#  '000068': '혼합',
#  '000069': '혼합',
#  '000070': '혼합',
#  '000071': '혼합',
#  '000072': '혼합',
#  '000073': '혼합',
#  '000074': '혼합',
# ...

# %%
df = get_preprocessed_menu8186_snapshot()
df
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
#                 일자                           펀드명  운용역  KOSPI지수  KOSDAQ지수  \
# 000005  2025-02-19             라이프IPO일반사모투자신탁제2호  남두우  2671.52    778.27
# 000006  2025-02-19     라이프IPO일반사모투자신탁제2호 Class C  남두우  2671.52    778.27
# 000012  2025-02-19          라이프IPO전문투자형사모투자신탁제3호  남두우  2671.52    778.27
# 000014  2025-02-19  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우  2671.52    778.27
# 000018  2025-02-19            라이프SPAC일반사모투자신탁제1호  남두우  2671.52    778.27
# ...            ...                           ...  ...      ...       ...
# A00011  2025-02-19                     한국증권금융 일임  이시우  2671.52    778.27
# A00012  2025-02-19                 라이프 주식 SJ 제3호  강대권  2671.52    778.27
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
data = get_data_of_columns_menu8186(cols=['펀드코드', '펀드명', '운용역'])
data
# Out:
# 1728 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250217-save20250218.csv
# DataFrame shape: (176, 40)
# [{'펀드코드': '000005', '펀드명': '라이프IPO일반사모투자신탁제2호', '운용역': '남두우'},
#  {'펀드코드': '000006', '펀드명': '라이프IPO일반사모투자신탁제2호 Class C', '운용역': '남두우'},
#  {'펀드코드': '000012', '펀드명': '라이프IPO전문투자형사모투자신탁제3호', '운용역': '남두우'},
#  {'펀드코드': '000014', '펀드명': '라이프IPO전문투자형사모투자신탁제3호 Class C', '운용역': '남두우'},
#  {'펀드코드': '000018', '펀드명': '라이프SPAC일반사모투자신탁제1호', '운용역': '남두우'},
#  {'펀드코드': '000019', '펀드명': '라이프SPAC일반사모투자신탁제1호 Class A', '운용역': '남두우'},
#  {'펀드코드': '00001I', '펀드명': '라이프SPAC일반사모투자신탁제1호 Class I', '운용역': '남두우'},
#  {'펀드코드': '000038', '펀드명': '라이프SPAC일반사모투자신탁제2호', '운용역': '남두우'},
#  {'펀드코드': '000039', '펀드명': '라이프 IPO코스닥벤처일반사모투자신탁제4호', '운용역': '남두우'},
#  {'펀드코드': '000040', '펀드명': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class A', '운용역': '남두우'},
# ...

# %%
from canonical_transformer import *
map_data_to_df(data)
# Out:
#        펀드코드                           펀드명  운용역
# 0    000005             라이프IPO일반사모투자신탁제2호  남두우
# 1    000006     라이프IPO일반사모투자신탁제2호 Class C  남두우
# 2    000012          라이프IPO전문투자형사모투자신탁제3호  남두우
# 3    000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우
# 4    000018            라이프SPAC일반사모투자신탁제1호  남두우
# ..      ...                           ...  ...
# 171  A00011                     한국증권금융 일임  이시우
# 172  A00012                 라이프 주식 SJ 제3호  강대권
# 173  A00013                   라이프 ESG형 7호  강대권
# 174  A00014                   라이프 ESG형 8호  강대권
# 175  A00015                TMF(라이프사회책임1호)  강대권
#
# [176 rows x 3 columns]

# %%
get_mapping_menu8186(col_for_range='펀드명')
# Out:
# 1728 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250217-save20250218.csv
# DataFrame shape: (176, 40)
# {'000005': '라이프IPO일반사모투자신탁제2호',
#  '000006': '라이프IPO일반사모투자신탁제2호 Class C',
#  '000012': '라이프IPO전문투자형사모투자신탁제3호',
#  '000014': '라이프IPO전문투자형사모투자신탁제3호 Class C',
#  '000018': '라이프SPAC일반사모투자신탁제1호',
#  '000019': '라이프SPAC일반사모투자신탁제1호 Class A',
#  '00001I': '라이프SPAC일반사모투자신탁제1호 Class I',
#  '000038': '라이프SPAC일반사모투자신탁제2호',
#  '000039': '라이프 IPO코스닥벤처일반사모투자신탁제4호',
#  '000040': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class A',
#  '000041': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class I',
#  '000042': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class S',
#  '000043': '라이프SPAC일반사모투자신탁제3호',
#  '000045': '라이프 IPO코스닥벤처일반사모투자신탁제5호',
#  '000046': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class A1',
#  '000048': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class C',
#  '000050': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class S',
# ...

# %%
get_mapping_menu8186(col_for_domain='펀드코드', col_for_range='설정일')
# Out:
# 1728 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250217-save20250218.csv
# DataFrame shape: (176, 40)
# {'000005': '2020-08-26',
#  '000006': '2020-08-26',
#  '000012': '2021-02-03',
#  '000014': '2021-02-03',
#  '000018': '2021-03-25',
#  '000019': '2021-03-25',
#  '00001I': '2024-01-10',
#  '000038': '2022-08-25',
#  '000039': '2023-03-30',
#  '000040': '2023-03-30',
#  '000041': '2023-04-10',
#  '000042': '2023-04-10',
#  '000043': '2023-05-08',
#  '000045': '2023-07-10',
#  '000046': '2023-07-10',
#  '000048': '2023-07-17',
#  '000050': '2023-07-10',
#  '000051': '2023-07-19',
#  '000053': '2023-08-17',
#  '000054': '2023-08-17',
#  '000055': '2023-08-24',
#  '000056': '2023-12-20',
#  '000057': '2023-12-20',
#  '000058': '2023-12-20',
#  '000059': '2024-01-02',
#  '000060': '2023-12-20',
#  '000061': '2024-01-24',
# ...

# %%
get_data_of_columns_menu8186(cols=['펀드코드', '펀드명', '설정일'])
# Out:
# 1728 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250217-save20250218.csv
# DataFrame shape: (176, 40)
# [{'펀드코드': '000005', '펀드명': '라이프IPO일반사모투자신탁제2호', '설정일': '2020-08-26'},
#  {'펀드코드': '000006', '펀드명': '라이프IPO일반사모투자신탁제2호 Class C', '설정일': '2020-08-26'},
#  {'펀드코드': '000012', '펀드명': '라이프IPO전문투자형사모투자신탁제3호', '설정일': '2021-02-03'},
#  {'펀드코드': '000014',
#   '펀드명': '라이프IPO전문투자형사모투자신탁제3호 Class C',
#   '설정일': '2021-02-03'},
#  {'펀드코드': '000018', '펀드명': '라이프SPAC일반사모투자신탁제1호', '설정일': '2021-03-25'},
#  {'펀드코드': '000019', '펀드명': '라이프SPAC일반사모투자신탁제1호 Class A', '설정일': '2021-03-25'},
#  {'펀드코드': '00001I', '펀드명': '라이프SPAC일반사모투자신탁제1호 Class I', '설정일': '2024-01-10'},
#  {'펀드코드': '000038', '펀드명': '라이프SPAC일반사모투자신탁제2호', '설정일': '2022-08-25'},
#  {'펀드코드': '000039', '펀드명': '라이프 IPO코스닥벤처일반사모투자신탁제4호', '설정일': '2023-03-30'},
#  {'펀드코드': '000040',
# ...

# %%
from canonical_transformer import *

# %%
get_preprocessed_menu2160(fund_code='000005')
get_timeseries_fund_price(fund_code='000005')
# Out:
# 29 Files matching the regex 'menu2160-code000005' in the bucket 'dataset-system' with prefix 'dataset-menu2160/':
# Successfully read file: dataset-menu2160/menu2160-code000005-from20200101-to20250216-save20250217.csv
# DataFrame shape: (1637, 23)
# 29 Files matching the regex 'menu2160-code000005' in the bucket 'dataset-system' with prefix 'dataset-menu2160/':
# Successfully read file: dataset-menu2160/menu2160-code000005-from20200101-to20250216-save20250217.csv
# DataFrame shape: (1637, 23)
#              000005
# date
# 2020-08-25  1000.00
# 2020-08-26  1000.01
# 2020-08-27  1000.01
# 2020-08-28  1000.02
# 2020-08-29  1000.03
# ...             ...
# 2025-02-12  1665.70
# 2025-02-13  1667.24
# 2025-02-14  1667.41
# 2025-02-15  1667.46
# 2025-02-16  1667.51
#
# [1637 rows x 1 columns]

# %%
menu8186_snapshot = get_preprocessed_menu8186_snapshot()
menu8186_snapshot
# Out:
# 1728 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250217-save20250218.csv
# DataFrame shape: (176, 40)
#              일자    펀드코드                           펀드명  운용역  KOSPI지수  KOSDAQ지수  \
# 순번
# 1    2025-02-17  000005             라이프IPO일반사모투자신탁제2호  남두우  2610.42    768.48
# 2    2025-02-17  000006     라이프IPO일반사모투자신탁제2호 Class C  남두우  2610.42    768.48
# 3    2025-02-17  000012          라이프IPO전문투자형사모투자신탁제3호  남두우  2610.42    768.48
# 4    2025-02-17  000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우  2610.42    768.48
# 5    2025-02-17  000018            라이프SPAC일반사모투자신탁제1호  남두우  2610.42    768.48
# ..          ...     ...                           ...  ...      ...       ...
# 172  2025-02-17  A00011                     한국증권금융 일임  이시우  2610.42    768.48
# 173  2025-02-17  A00012                 라이프 주식 SJ 제3호  강대권  2610.42    768.48
# ...

# %%
cols_for_mapping_pairs = ['펀드명']
df_code_name = menu8186_snapshot.set_index('펀드코드')[cols_for_mapping_pairs]
df_code_name
# Out:
#                                  펀드명
# 펀드코드
# 000005             라이프IPO일반사모투자신탁제2호
# 000006     라이프IPO일반사모투자신탁제2호 Class C
# 000012          라이프IPO전문투자형사모투자신탁제3호
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C
# 000018            라이프SPAC일반사모투자신탁제1호
# ...                              ...
# A00011                     한국증권금융 일임
# A00012                 라이프 주식 SJ 제3호
# A00013                   라이프 ESG형 7호
# A00014                   라이프 ESG형 8호
# A00015                TMF(라이프사회책임1호)
#
# [176 rows x 1 columns]

# %%
data = map_df_to_data(df_code_name)
data
# Out:
# [{'펀드코드': '000005', '펀드명': '라이프IPO일반사모투자신탁제2호'},
#  {'펀드코드': '000006', '펀드명': '라이프IPO일반사모투자신탁제2호 Class C'},
#  {'펀드코드': '000012', '펀드명': '라이프IPO전문투자형사모투자신탁제3호'},
#  {'펀드코드': '000014', '펀드명': '라이프IPO전문투자형사모투자신탁제3호 Class C'},
#  {'펀드코드': '000018', '펀드명': '라이프SPAC일반사모투자신탁제1호'},
#  {'펀드코드': '000019', '펀드명': '라이프SPAC일반사모투자신탁제1호 Class A'},
#  {'펀드코드': '00001I', '펀드명': '라이프SPAC일반사모투자신탁제1호 Class I'},
#  {'펀드코드': '000038', '펀드명': '라이프SPAC일반사모투자신탁제2호'},
#  {'펀드코드': '000039', '펀드명': '라이프 IPO코스닥벤처일반사모투자신탁제4호'},
#  {'펀드코드': '000040', '펀드명': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class A'},
#  {'펀드코드': '000041', '펀드명': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class I'},
#  {'펀드코드': '000042', '펀드명': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class S'},
#  {'펀드코드': '000043', '펀드명': '라이프SPAC일반사모투자신탁제3호'},
#  {'펀드코드': '000045', '펀드명': '라이프 IPO코스닥벤처일반사모투자신탁제5호'},
#  {'펀드코드': '000046', '펀드명': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class A1'},
#  {'펀드코드': '000048', '펀드명': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class C'},
# ...

# %%
{datum['펀드코드']: datum['펀드명'] for datum in data}
# Out:
# {'000005': '라이프IPO일반사모투자신탁제2호',
#  '000006': '라이프IPO일반사모투자신탁제2호 Class C',
#  '000012': '라이프IPO전문투자형사모투자신탁제3호',
#  '000014': '라이프IPO전문투자형사모투자신탁제3호 Class C',
#  '000018': '라이프SPAC일반사모투자신탁제1호',
#  '000019': '라이프SPAC일반사모투자신탁제1호 Class A',
#  '00001I': '라이프SPAC일반사모투자신탁제1호 Class I',
#  '000038': '라이프SPAC일반사모투자신탁제2호',
#  '000039': '라이프 IPO코스닥벤처일반사모투자신탁제4호',
#  '000040': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class A',
#  '000041': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class I',
#  '000042': '라이프IPO코스닥벤처일반사모투자신탁제4호 Class S',
#  '000043': '라이프SPAC일반사모투자신탁제3호',
#  '000045': '라이프 IPO코스닥벤처일반사모투자신탁제5호',
#  '000046': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class A1',
#  '000048': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class C',
#  '000050': '라이프IPO코스닥벤처일반사모투자신탁제5호 Class S',
#  '000051': '라이프 KBIZ 알파 일반사모투자신탁(전문) 2023-가',
#  '000053': '라이프IPO하이일드일반사모투자신탁제5호',
#  '000054': '라이프IPO하이일드일반사모투자신탁제5호 Class A',
#  '000055': '라이프IPO하이일드일반사모투자신탁제5호 Class C',
#  '000056': '라이프IPO코스닥벤처일반사모투자신탁제6호',
#  '000057': '라이프IPO코스닥벤처일반사모투자신탁제6호 Class A',
# ...

# %%
menu8186_snapshot.columns
# Out:
# Index(['일자', '펀드코드', '펀드명', '운용역', 'KOSPI지수', 'KOSDAQ지수', 'KOSPI200지수', '기준가격',
#        '기준가격: 증감', '과표기준가', '과표기준가: 증감', '해외비과세과표기준가', '해외비과세과표기준가: 증감',
#        '비거주자과표기준가', '수정기준가', '순자산', '수탁사', '설정일', '설정좌수', '설정액', '펀드유형',
#        '과표구분', '신탁구분', '사무수탁사', '주식비율', '채권비율', '주식순비율', '채권순비율', '지수선물순비율',
#        '국고채3년금리', '국고채5년금리', '통안채2년금리', 'CD91', '전일대비수익률', '주간수익률(%)',
#        '1개월수익률(%)', '3개월수익률(%)', '12개월수익률(%)', 'BM기준가', '전일대비BM수익률(%)'],
#       dtype='object')

# %%
df = load_menu8186_snapshot(date_ref='2025-02-16')
df
# Out:
# 1 Files matching the regex 'menu8186-code000000-at20250216' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250216-save20250217.csv
# DataFrame shape: (174, 40)
#              일자    펀드코드                           펀드명  운용역   KOSPI지수  \
# 순번
# 1    2025-02-16  000005             라이프IPO일반사모투자신탁제2호  남두우  2,591.05
# 2    2025-02-16  000006     라이프IPO일반사모투자신탁제2호 Class C  남두우  2,591.05
# 3    2025-02-16  000012          라이프IPO전문투자형사모투자신탁제3호  남두우  2,591.05
# 4    2025-02-16  000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우  2,591.05
# 5    2025-02-16  000018            라이프SPAC일반사모투자신탁제1호  남두우  2,591.05
# ..          ...     ...                           ...  ...       ...
# 170  2025-02-16  A00011                     한국증권금융 일임  이시우  2,591.05
# 171  2025-02-16  A00012                 라이프 주식 SJ 제3호  강대권  2,591.05
# 172  2025-02-16  A00013                   라이프 ESG형 7호  강대권  2,591.05
# ...

# %%
col = get_preprocessed_column_names_menu8186(df)
col
# Out:
# ['일자',
#  '펀드코드',
#  '펀드명',
#  '운용역',
#  'KOSPI지수',
#  'KOSDAQ지수',
#  'KOSPI200지수',
#  '기준가격',
#  '기준가격: 증감',
#  '과표기준가',
#  '과표기준가: 증감',
#  '해외비과세과표기준가',
#  '해외비과세과표기준가: 증감',
#  '비거주자과표기준가',
#  '수정기준가',
#  '순자산',
#  '수탁사',
#  '설정일',
#  '설정좌수',
#  '설정액',
#  '펀드유형',
#  '과표구분',
#  '신탁구분',
#  '사무수탁사',
#  '주식비율',
#  '채권비율',
#  '주식순비율',
#  '채권순비율',
#  '지수선물순비율',
#  '국고채3년금리',
#  '국고채5년금리',
#  '통안채2년금리',
#  'CD91',
#  '전일대비수익률',
#  '주간수익률(%)',
#  '1개월수익률(%)',
#  '3개월수익률(%)',
#  '12개월수익률(%)',
#  'BM기준가',
#  '전일대비BM수익률(%)']

# %%
df.columns = col
df
# Out:
#              일자    펀드코드                           펀드명  운용역   KOSPI지수  \
# 순번
# 1    2025-02-16  000005             라이프IPO일반사모투자신탁제2호  남두우  2,591.05
# 2    2025-02-16  000006     라이프IPO일반사모투자신탁제2호 Class C  남두우  2,591.05
# 3    2025-02-16  000012          라이프IPO전문투자형사모투자신탁제3호  남두우  2,591.05
# 4    2025-02-16  000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우  2,591.05
# 5    2025-02-16  000018            라이프SPAC일반사모투자신탁제1호  남두우  2,591.05
# ..          ...     ...                           ...  ...       ...
# 170  2025-02-16  A00011                     한국증권금융 일임  이시우  2,591.05
# 171  2025-02-16  A00012                 라이프 주식 SJ 제3호  강대권  2,591.05
# 172  2025-02-16  A00013                   라이프 ESG형 7호  강대권  2,591.05
# 173  2025-02-16  A00014                   라이프 ESG형 8호  강대권  2,591.05
# 174  2025-02-16  A00015                TMF(라이프사회책임1호)  강대권  2,591.05
#
#      KOSDAQ지수  KOSPI200지수      기준가격  기준가격: 증감     과표기준가  ...  국고채5년금리  \
# 순번                                                       ...
# ...

# %%
df.iloc[0]
# Out:
# 일자                       2025-02-16
# 펀드코드                         000005
# 펀드명               라이프IPO일반사모투자신탁제2호
# 운용역                             남두우
# KOSPI지수                    2,591.05
# KOSDAQ지수                     756.32
# KOSPI200지수                   342.76
# 기준가격                       1,014.31
# 기준가격: 증감                       0.03
# 과표기준가                      1,007.87
# 과표기준가: 증감                      0.03
# 해외비과세과표기준가                      0.0
# 해외비과세과표기준가: 증감                  0.0
# 비거주자과표기준가                       0.0
# 수정기준가                      1,667.49
# 순자산                   3,128,686,100
# 수탁사                            신한은행
# 설정일                      2020-08-26
# 설정좌수                  3,084,553,331
# 설정액                   3,084,553,331
# 펀드유형                             주혼
# 과표구분                             배당
# 신탁구분                           투자신탁
# 사무수탁사                      KB펀드파트너스
# 주식비율                            1.3
# 채권비율                            0.0
# ...

# %%
data = {'col1': df.columns, 'col2': None}
df = pd.DataFrame(data)
df
# Out:
#             col1  col2
# 0             일자  None
# 1           펀드코드  None
# 2            펀드명  None
# 3            운용역  None
# 4        KOSPI지수  None
# 5       KOSDAQ지수  None
# 6     KOSPI200지수  None
# 7           기준가격  None
# 8             증감  None
# 9          과표기준가  None
# 10          증감.1  None
# 11    해외비과세과표기준가  None
# 12          증감.2  None
# 13     비거주자과표기준가  None
# 14         수정기준가  None
# 15           순자산  None
# 16           수탁사  None
# 17           설정일  None
# 18          설정좌수  None
# 19           설정액  None
# 20          펀드유형  None
# 21          과표구분  None
# 22          신탁구분  None
# 23         사무수탁사  None
# 24          주식비율  None
# 25          채권비율  None
# 26         주식순비율  None
# 27         채권순비율  None
# 28       지수선물순비율  None
# 29       국고채3년금리  None
# 30       국고채5년금리  None
# 31       통안채2년금리  None
# 32          CD91  None
# 33       전일대비수익률  None
# 34      주간수익률(%)  None
# 35     1개월수익률(%)  None
# 36     3개월수익률(%)  None
# 37    12개월수익률(%)  None
# 38         BM기준가  None
# ...

# %%
df.columns
# Out:
# Index(['일자', '펀드코드', '펀드명', '운용역', 'KOSPI지수', 'KOSDAQ지수', 'KOSPI200지수', '기준가격',
#        '증감', '과표기준가', '증감.1', '해외비과세과표기준가', '증감.2', '비거주자과표기준가', '수정기준가',
#        '순자산', '수탁사', '설정일', '설정좌수', '설정액', '펀드유형', '과표구분', '신탁구분', '사무수탁사',
#        '주식비율', '채권비율', '주식순비율', '채권순비율', '지수선물순비율', '국고채3년금리', '국고채5년금리',
#        '통안채2년금리', 'CD91', '전일대비수익률', '주간수익률(%)', '1개월수익률(%)', '3개월수익률(%)',
#        '12개월수익률(%)', 'BM기준가', '전일대비BM수익률(%)'],
#       dtype='object')

# %%
# basis functions

import pandas as pd
from pandas import DataFrame
from typing import Dict, List

COLUMN_NAME_FOR_RETURN = '증감'
COLUMN_NAME_TOBE_ELIMINATED = 'Unnamed:'
CHARACTER_TOBE_REPLACED = '\n'
CHARACTER_TOBE_SPLITTED = '.'
COLUMN_NAME_FOR_HEADER_01 = 'col1'
COLUMN_NAME_FOR_HEADER_02 = 'col2'
COLUMN_NAME_FOR_PREPROCESSED = 'col' 


def get_data_of_double_columns_in_raw_csv_dataset(df: DataFrame) -> Dict[str, List[str]]:
    return {
        COLUMN_NAME_FOR_HEADER_01: list(df.columns),
        COLUMN_NAME_FOR_HEADER_02: list(df.iloc[0])
    }

def get_data_od_single_column_in_raw_csv_dataset(df):
    return {
        COLUMN_NAME_FOR_HEADER_01: list(df.columns),
        COLUMN_NAME_FOR_HEADER_02: list(df.iloc[0])
    }

def create_initial_df_col(df: DataFrame) -> DataFrame:
    return pd.DataFrame(data=get_data_of_double_columns_in_raw_csv_dataset(df))

def clean_col1(df: DataFrame) -> DataFrame:
    return df.assign(
        col1=df[COLUMN_NAME_FOR_HEADER_01].apply(lambda x: x.replace(CHARACTER_TOBE_REPLACED,'').split(CHARACTER_TOBE_SPLITTED)[0])
                           .apply(lambda x: None if COLUMN_NAME_TOBE_ELIMINATED in x else x)
    )

def process_return_column_from_col1_to_col2(df: DataFrame) -> DataFrame:
    return df.assign(
        col2=df.apply(lambda x: x[COLUMN_NAME_FOR_HEADER_01] if x[COLUMN_NAME_FOR_HEADER_01]==COLUMN_NAME_FOR_RETURN else x[COLUMN_NAME_FOR_HEADER_02], axis=1)
           .apply(lambda x: '' if pd.isna(x) else x)
    )

def fill_col1_values(df: DataFrame) -> DataFrame:
    return df.assign(
        col1=df[COLUMN_NAME_FOR_HEADER_01].apply(lambda x: None if x==COLUMN_NAME_FOR_RETURN else x).ffill()
    )

def combine_columns(df: DataFrame) -> DataFrame:
    return df.assign(
        col=df.apply(lambda x: f"{x[COLUMN_NAME_FOR_HEADER_01]}: {x[COLUMN_NAME_FOR_HEADER_02]}" if x[COLUMN_NAME_FOR_HEADER_02]!='' else x[COLUMN_NAME_FOR_HEADER_01], axis=1)
    )

# %%
df = clean_col1(df)
df = process_return_column_from_col1_to_col2(df)
df = fill_col1_values(df)
df = combine_columns(df)
df
# Out:
#             col1 col2             col
# 0             일자                   일자
# 1           펀드코드                 펀드코드
# 2            펀드명                  펀드명
# 3            운용역                  운용역
# 4        KOSPI지수              KOSPI지수
# 5       KOSDAQ지수             KOSDAQ지수
# 6     KOSPI200지수           KOSPI200지수
# 7           기준가격                 기준가격
# 8           기준가격   증감        기준가격: 증감
# 9          과표기준가                과표기준가
# 10         과표기준가   증감       과표기준가: 증감
# 11    해외비과세과표기준가           해외비과세과표기준가
# 12    해외비과세과표기준가   증감  해외비과세과표기준가: 증감
# 13     비거주자과표기준가            비거주자과표기준가
# 14         수정기준가                수정기준가
# 15           순자산                  순자산
# 16           수탁사                  수탁사
# 17           설정일                  설정일
# 18          설정좌수                 설정좌수
# 19           설정액                  설정액
# 20          펀드유형                 펀드유형
# 21          과표구분                 과표구분
# 22          신탁구분                 신탁구분
# 23         사무수탁사                사무수탁사
# ...

# %%
df.columns
# Out:
# Index(['일자', '펀드코드', '펀드명', '운용역', 'KOSPI지수', 'KOSDAQ지수', 'KOSPI200지수', '기준가격',
#        '증감', '과표기준가', '증감.1', '해외비과세과표기준가', '증감.2', '비거주자과표기준가', '수정기준가',
#        '순자산', '수탁사', '설정일', '설정좌수', '설정액', '펀드유형', '과표구분', '신탁구분', '사무수탁사',
#        '주식비율', '채권비율', '주식순비율', '채권순비율', '지수선물순비율', '국고채3년금리', '국고채5년금리',
#        '통안채2년금리', 'CD91', '전일대비수익률', '주간수익률(%)', '1개월수익률(%)', '3개월수익률(%)',
#        '12개월수익률(%)', 'BM기준가', '전일대비BM수익률(%)'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# 일자                     2025-02-16
# 펀드코드                       000005
# 펀드명             라이프IPO일반사모투자신탁제2호
# 운용역                           남두우
# KOSPI지수                  2,591.05
# KOSDAQ지수                   756.32
# KOSPI200지수                 342.76
# 기준가격                     1,014.31
# 증감                           0.03
# 과표기준가                    1,007.87
# 증감.1                         0.03
# 해외비과세과표기준가                    0.0
# 증감.2                          0.0
# 비거주자과표기준가                     0.0
# 수정기준가                    1,667.49
# 순자산                 3,128,686,100
# 수탁사                          신한은행
# 설정일                    2020-08-26
# 설정좌수                3,084,553,331
# 설정액                 3,084,553,331
# 펀드유형                           주혼
# 과표구분                           배당
# 신탁구분                         투자신탁
# 사무수탁사                    KB펀드파트너스
# 주식비율                          1.3
# 채권비율                          0.0
# 주식순비율                         1.3
# ...
