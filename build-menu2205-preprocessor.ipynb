# %%
from financial_dataset_preprocessor import *
from canonical_transformer import map_df_to_some_data, map_df_to_data
# Out:
# INFO:shining_pebbles:shining_pebbles package initialized

# %%
bonds100060 = get_domestic_bonds_by_fund(fund_code='100060')
bonds100060
# Out:
# 193 Files matching the regex 'menu2205-code100060' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code100060-at20250219-save20250220.csv
# DataFrame shape: (101, 78)
#               자산                   종목명            종목  원화 보유정보: 액면금액  \
# 2025-02-19  국내채권  국고채권03000-2909(24-7)  KR103501GE98     1000000000
# 2025-02-19  국내채권  국고채권02875-2609(24-9)  KR103503GE96     2000000000
# 2025-02-19  국내채권       뉴스타이천제일차 전자단기사채  KR9F13142001     2200000000
# 2025-02-19  국내채권          화이트비버 전자단기사채  KR9F20742001     3000000000
# 2025-02-19  국내채권                    소계           4 건     8200000000
#
#             원화 보유정보: 매매가능액면금액  원화 보유정보: 장부가액  원화 보유정보: 평가액  원화 보유정보: 취득액  \
# 2025-02-19         1000000000   1.024335e+09  1.024241e+09  1.010827e+09
# 2025-02-19         2000000000   2.029513e+09  2.031134e+09  2.003622e+09
# 2025-02-19         2200000000   2.198264e+09  2.198365e+09  2.193924e+09
# ...

# %%
bonds = get_domestic_bonds()
bonds
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
#               자산                     종목명            종목  원화 보유정보: 액면금액  \
# 2025-02-19  국내채권    국고채권03000-2909(24-7)  KR103501GE98     1000000000
# 2025-02-19  국내채권    국고채권03375-2503(23-3)  KR103503GD30    10000000000
# 2025-02-19  국내채권    국고채권02875-2609(24-9)  KR103503GE96     2000000000
# 2025-02-19  국내채권  농업금융채권(은행)2023-03이2Y-C  KR381003GD37    10000000000
# 2025-02-19  국내채권            한국전력공사채권1381  KR350105GD47    10000000000
# ...          ...                     ...           ...            ...
# 2025-02-19  국내채권            화이트비버 전자단기사채  KR9F20742002      700000000
# 2025-02-19  국내채권            화이트비버 전자단기사채  KR9F20742003      300000000
# 2025-02-19  국내채권            화이트비버 전자단기사채  KR9F20742004     1000000000
# ...

# %%
bonds = get_domestic_bonds()
# bonds.iloc[[0]].T
map_df_to_data(bonds.iloc[[0]].T.reset_index())
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
# [{'index': '자산', '2025-02-19': '국내채권'},
#  {'index': '종목명', '2025-02-19': '국고채권03000-2909(24-7)'},
#  {'index': '종목', '2025-02-19': 'KR103501GE98'},
#  {'index': '원화 보유정보: 수량', '2025-02-19': 1000000000},
#  {'index': '원화 보유정보: 매매가능수량', '2025-02-19': 1000000000},
#  {'index': '원화 보유정보: 장부가액', '2025-02-19': 1024335429.0},
#  {'index': '원화 보유정보: 평가액', '2025-02-19': 1024241000.0},
#  {'index': '원화 보유정보: 취득액', '2025-02-19': 1010827142.0},
#  {'index': '원화 보유정보: 평가손익', '2025-02-19': -94429.0},
#  {'index': '원화 보유정보: 손익률', '2025-02-19': -0.01},
#  {'index': '원화 보유정보: 취득단가', '2025-02-19': 0.0},
#  {'index': '원화 보유정보: 미수이자', '2025-02-19': 3066299.0},
#  {'index': '원화 보유정보: 선급비용', '2025-02-19': 10441988.0},
# ...

# %%
dfs = get_grouped_dfs_of_menu2205(col='자산', date_ref=None)
dfs
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
# {'REPO':               자산 종목명    종목   원화 보유정보: 수량  원화 보유정보: 매매가능수량  원화 보유정보: 장부가액  \
#  2025-02-19  REPO  소계  35 건  147000000000     147000000000   1.470121e+11
#
#              원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 평가손익  원화 보유정보: 손익률  ...  \
#  2025-02-19  1.470121e+11  1.470000e+11            0.0           0.0  ...
#
#              종목정보: 발행기관  종목정보: 이자지급방법  종목정보: 자산분류  종목정보: 시가총액     자산정보: 순자산  \
#  2025-02-19         NaN           NaN         NaN         0.0  2.568999e+12
#
#                 자산정보: 총자산  자산정보: 기준가격  자산정보: 증감  자산정보: ISIN코드  자산정보: TICKER
#  2025-02-19  2.591705e+12     1080.47      1.43           NaN           NaN
#
#  [1 rows x 78 columns],
# ...

# %%
get_domestic_stocks()
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_domestic_stocks()
#
# File ~/dev/module-financial_dataset_preprocessor/financial_dataset_preprocessor/menu2205_preprocessor/menu2205_applications/domestic_stocks.py:10, in get_domestic_stocks(date_ref)
#       8 def get_domestic_stocks(date_ref=None):
#       9     col = '국내주식'
# ---> 10     dfs = get_grouped_dfs_of_menu2205(col=col, date_ref=date_ref)
#      11     domestic_stocks = dfs[col][COLUMNS_FOR_DOMESTIC_STOCKS]
#      12     return domestic_stocks
#
# ...

# %%
df = get_preprocessed_menu2205_snapshot()
df.columns
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
# Index(['자산', '종목명', '종목', '원화 보유정보: 수량', '원화 보유정보: 매매가능수량', '원화 보유정보: 장부가액',
#        '원화 보유정보: 평가액', '원화 보유정보: 취득액', '원화 보유정보: 평가손익', '원화 보유정보: 손익률',
#        '원화 보유정보: 취득단가', '원화 보유정보: 미수이자', '원화 보유정보: 선급비용', '원화 보유정보: 상환손익',
#        '외화 보유정보: 외화취득액', '외화 보유정보: 외화평가액', '외화 보유정보: 손익률', '외화 보유정보: 취득단가',
#        '비중: 주식/채권', '비중: 자산대비', '비중: 시장대비', '비중: 시장비중', '대여정보: 대용/담보수량',
#        '대여정보: 대여수량', '대여정보: 대용비율', '대여정보: 대여비율', '평가정보: 종가', '평가정보: 증감',
#        '평가정보: 시가수익률', '평가정보: 증감', '평가정보: 3사평균', '평가정보: 4사평균', '평가정보: KBP가격',
#        '평가정보: NICE가격', '평가정보: KIS가격', '평가정보: FNP가격', '평가정보: 3사평균YTM',
#        '평가정보: 4사평균YTM', '평가정보: KBP YTM', '평가정보: NICE YTM', '평가정보: KIS YTM',
# ...

# %%
get_borriwings()
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
#              자산                         종목명            종목  원화 보유정보: 장부가액  \
# 2025-02-19  차입금          신용대출20250311(KB증권)  KRMN24121101   3.006288e+09
# 2025-02-19  차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001   1.703634e+09
# 2025-02-19  차입금  신용대출20250520(한국투자증권(PB고유))  KRMN25021901   8.500969e+09
# 2025-02-19  차입금                          소계           3 건   1.321089e+10
#
#             원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 미수이자  종목정보: 표면금리  \
# 2025-02-19  3.006288e+09  3.000000e+09      6287671.0        4.50
# 2025-02-19  1.703634e+09  1.700000e+09      3634274.0        4.59
# 2025-02-19  8.500969e+09  8.500000e+09       968767.0        4.16
# 2025-02-19  1.321089e+10  1.320000e+10     10890712.0         NaN
#
# ...

# %%
get_borriwings_by_fund(fund_code='100077', date_ref=None)
# Out:
# 194 Files matching the regex 'menu2205-code100077' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code100077-at20250219-save20250220.csv
# DataFrame shape: (20, 78)
#              자산                         종목명            종목  원화 보유정보: 장부가액  \
# 2025-02-19  차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001   1.703634e+09
# 2025-02-19  차입금  신용대출20250520(한국투자증권(PB고유))  KRMN25021901   8.500969e+09
# 2025-02-19  차입금                          소계           2 건   1.020460e+10
#
#             원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 미수이자  종목정보: 표면금리  \
# 2025-02-19  1.703634e+09  1.700000e+09      3634274.0        4.59
# 2025-02-19  8.500969e+09  8.500000e+09       968767.0        4.16
# 2025-02-19  1.020460e+10  1.020000e+10      4603041.0         NaN
#
#             종목정보: 회계적수익률   종목정보: 발행일   종목정보: 만기일  종목정보: 잔존일수 종목정보: 발행기관  \
# 2025-02-19          4.58  2024-12-20  2025-03-21        30.0     한국투자증권
# ...

# %%
fund_codes = get_all_fund_codes()
dct_dfs = {}
for fund_code in fund_codes:
    try:
        dct_dfs[fund_code] = get_borriwings_by_fund(fund_code=fund_code, date_ref=None)
    except:
        dct_dfs[fund_code] = None
dct_dfs
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# 197 Files matching the regex 'menu2205-code000005' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code000005-at20250219-save20250220.csv
# DataFrame shape: (17, 78)
# 197 Files matching the regex 'menu2205-code000006' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code000006-at20250219-save20250220.csv
# DataFrame shape: (3, 78)
# 197 Files matching the regex 'menu2205-code000012' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code000012-at20250219-save20250220.csv
# DataFrame shape: (9, 78)
# ...

# %%
dct_dfs
# Out:
# {'000005': None,
#  '000006': None,
#  '000012': None,
#  '000014': None,
#  '000018': None,
#  '000019': None,
#  '00001I': None,
#  '000038': None,
#  '000039': None,
#  '000040': None,
#  '000041': None,
#  '000042': None,
#  '000043': None,
#  '000045': None,
#  '000046': None,
#  '000048': None,
#  '000050': None,
#  '000051': None,
#  '000053': None,
#  '000054': None,
#  '000055': None,
#  '000056': None,
#  '000057': None,
#  '000058': None,
#  '000059': None,
#  '000060': None,
#  '000061': None,
#  '000062': None,
#  '000063': None,
#  '000065': None,
#  '000066': None,
#  '000067': None,
#  '000068': None,
#  '000069': None,
#  '000070': None,
#  '000071': None,
#  '000072': None,
#  '000073': None,
#  '000074': None,
#  '000075': None,
#  '000076': None,
#  '000077': None,
#  '000079': None,
#  '000080': None,
#  '000082': None,
#  '000083': None,
#  '000084': None,
#  '000085': None,
#  '000087': None,
#  '000088': None,
#  '000089': None,
#  '000090': None,
# ...

# %%
dct_borrowings = {k: v for k, v in dct_dfs.items() if v is not None}
dct_borrowings
# Out:
# {'100077':              자산                         종목명            종목  원화 보유정보: 장부가액  \
#  2025-02-19  차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001   1.703634e+09
#  2025-02-19  차입금  신용대출20250520(한국투자증권(PB고유))  KRMN25021901   8.500969e+09
#  2025-02-19  차입금                          소계           2 건   1.020460e+10
#
#              원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 미수이자  종목정보: 표면금리  \
#  2025-02-19  1.703634e+09  1.700000e+09      3634274.0        4.59
#  2025-02-19  8.500969e+09  8.500000e+09       968767.0        4.16
#  2025-02-19  1.020460e+10  1.020000e+10      4603041.0         NaN
#
#              종목정보: 회계적수익률   종목정보: 발행일   종목정보: 만기일  종목정보: 잔존일수 종목정보: 발행기관  \
#  2025-02-19          4.58  2024-12-20  2025-03-21        30.0     한국투자증권
#  2025-02-19          4.16  2025-02-19  2025-05-20        90.0     한국투자증권
#  2025-02-19           NaN         NaN         NaN         NaN        NaN
#
#               종목정보: 만기일
#  2025-02-19  2025-03-21
#  2025-02-19  2025-05-20
# ...

# %%
dct_borrowings['100106']
# Out:
#              자산                 종목명            종목  원화 보유정보: 장부가액  \
# 2025-02-19  차입금  신용대출20250311(KB증권)  KRMN24121101   3.006288e+09
# 2025-02-19  차입금                  소계           1 건   3.006288e+09
#
#             원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 미수이자  종목정보: 표면금리  \
# 2025-02-19  3.006288e+09  3.000000e+09      6287671.0         4.5
# 2025-02-19  3.006288e+09  3.000000e+09      6287671.0         NaN
#
#             종목정보: 회계적수익률   종목정보: 발행일   종목정보: 만기일  종목정보: 잔존일수 종목정보: 발행기관  \
# 2025-02-19         4.491  2024-12-11  2025-03-11        20.0       KB증권
# 2025-02-19           NaN         NaN         NaN         NaN        NaN
#
#              종목정보: 만기일
# 2025-02-19  2025-03-11
# 2025-02-19         NaN

# %%
get_all_fund_names()['100106']
# Out:
# 1730 Files matching the regex 'menu8186-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu8186-snapshot/':
# Successfully read file: dataset-menu8186-snapshot/menu8186-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 40)
# '라이프 Engagement 일반사모투자신탁 제7호'

# %%
df = get_preprocessed_menu2205_snapshot(date_ref=None)
df
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
#                자산                         종목명            종목  원화 보유정보: 수량  \
# 2025-02-19   국내주식                        삼양식품  KR7003230000          104
# 2025-02-19   국내주식                         오뚜기  KR7007310006         3417
# 2025-02-19   국내주식                        KT&G  KR7033780008         6238
# 2025-02-19   국내주식                         삼양사  KR7145990008        96133
# 2025-02-19   국내주식                         오리온  KR7271560005      1018091
# ...           ...                         ...           ...          ...
# 2025-02-19  총계정원장                          소계           3 건            0
# 2025-02-19    차입금          신용대출20250311(KB증권)  KRMN24121101   3000000000
# ...

# %%
dfs = get_grouped_dfs_of_df(df, '자산')
dfs
# Out:
# {'REPO':               자산 종목명    종목   원화 보유정보: 수량  원화 보유정보: 매매가능수량  원화 보유정보: 장부가액  \
#  2025-02-19  REPO  소계  35 건  147000000000     147000000000   1.470121e+11
#
#              원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 평가손익  원화 보유정보: 손익률  ...  \
#  2025-02-19  1.470121e+11  1.470000e+11            0.0           0.0  ...
#
#              종목정보: 발행기관  종목정보: 이자지급방법  종목정보: 자산분류  종목정보: 시가총액     자산정보: 순자산  \
#  2025-02-19         NaN           NaN         NaN         0.0  2.568999e+12
#
#                 자산정보: 총자산  자산정보: 기준가격  자산정보: 증감  자산정보: ISIN코드  자산정보: TICKER
#  2025-02-19  2.591705e+12     1080.47      1.43           NaN           NaN
#
#  [1 rows x 78 columns],
#  'REPO 매수':                  자산             종목명            종목  원화 보유정보: 수량  \
#  2025-02-19  REPO 매수  REPO(매수) 56115  KRRP25219001   1000000000
#  2025-02-19  REPO 매수  REPO(매수) 56128  KRRP25219002   1000000000
#  2025-02-19  REPO 매수  REPO(매수) 56137  KRRP25219003   1000000000
# ...

# %%
dfs = get_grouped_dfs_of_df(df, '자산')
borrowings = dfs['차입금']
borrowings
# Out:
#              자산                         종목명            종목  원화 보유정보: 수량  \
# 2025-02-19  차입금          신용대출20250311(KB증권)  KRMN24121101   3000000000
# 2025-02-19  차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001   1700000000
# 2025-02-19  차입금  신용대출20250520(한국투자증권(PB고유))  KRMN25021901   8500000000
# 2025-02-19  차입금                          소계           3 건  13200000000
#
#             원화 보유정보: 매매가능수량  원화 보유정보: 장부가액  원화 보유정보: 평가액  원화 보유정보: 취득액  \
# 2025-02-19       3000000000   3.006288e+09  3.006288e+09  3.000000e+09
# 2025-02-19       1700000000   1.703634e+09  1.703634e+09  1.700000e+09
# 2025-02-19       8500000000   8.500969e+09  8.500969e+09  8.500000e+09
# 2025-02-19      13200000000   1.321089e+10  1.321089e+10  1.320000e+10
#
#             원화 보유정보: 평가손익  원화 보유정보: 손익률  ...  종목정보: 발행기관  종목정보: 이자지급방법  \
# 2025-02-19            0.0           0.0  ...        KB증권            후취
# 2025-02-19            0.0           0.0  ...      한국투자증권            후취
# ...

# %%
borrowings_columns = [
    '자산',
    '종목명',
    '종목',
    '원화 보유정보: 장부가액',
    '원화 보유정보: 평가액',
    '원화 보유정보: 취득액',
    '원화 보유정보: 미수이자',
    '종목정보: 표면금리',
    '종목정보: 회계적수익률',
    '종목정보: 발행일',
    '종목정보: 만기일',
    '종목정보: 잔존일수',
    '종목정보: 발행기관',  # 차입처
    '종목정보: 만기일'     # 차입 만기일
]

borrowings_filtered = borrowings[borrowings['자산'] == '차입금'][borrowings_columns]
borrowings_filtered
# Out:
#              자산                         종목명            종목  원화 보유정보: 장부가액  \
# 2025-02-19  차입금          신용대출20250311(KB증권)  KRMN24121101   3.006288e+09
# 2025-02-19  차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001   1.703634e+09
# 2025-02-19  차입금  신용대출20250520(한국투자증권(PB고유))  KRMN25021901   8.500969e+09
# 2025-02-19  차입금                          소계           3 건   1.321089e+10
#
#             원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 미수이자  종목정보: 표면금리  \
# 2025-02-19  3.006288e+09  3.000000e+09      6287671.0        4.50
# 2025-02-19  1.703634e+09  1.700000e+09      3634274.0        4.59
# 2025-02-19  8.500969e+09  8.500000e+09       968767.0        4.16
# 2025-02-19  1.321089e+10  1.320000e+10     10890712.0         NaN
#
#             종목정보: 회계적수익률   종목정보: 발행일   종목정보: 만기일  종목정보: 잔존일수 종목정보: 발행기관  \
# 2025-02-19         4.491  2024-12-11  2025-03-11        20.0       KB증권
# 2025-02-19         4.580  2024-12-20  2025-03-21        30.0     한국투자증권
# ...

# %%
borrowings.columns
# Out:
# Index(['자산', '종목명', '종목', '원화 보유정보: 수량', '원화 보유정보: 매매가능수량', '원화 보유정보: 장부가액',
#        '원화 보유정보: 평가액', '원화 보유정보: 취득액', '원화 보유정보: 평가손익', '원화 보유정보: 손익률',
#        '원화 보유정보: 취득단가', '원화 보유정보: 미수이자', '원화 보유정보: 선급비용', '원화 보유정보: 상환손익',
#        '외화 보유정보: 외화취득액', '외화 보유정보: 외화평가액', '외화 보유정보: 손익률', '외화 보유정보: 취득단가',
#        '비중: 주식/채권', '비중: 자산대비', '비중: 시장대비', '비중: 시장비중', '대여정보: 대용/담보수량',
#        '대여정보: 대여수량', '대여정보: 대용비율', '대여정보: 대여비율', '평가정보: 종가', '평가정보: 증감',
#        '평가정보: 시가수익률', '평가정보: 증감', '평가정보: 3사평균', '평가정보: 4사평균', '평가정보: KBP가격',
#        '평가정보: NICE가격', '평가정보: KIS가격', '평가정보: FNP가격', '평가정보: 3사평균YTM',
#        '평가정보: 4사평균YTM', '평가정보: KBP YTM', '평가정보: NICE YTM', '평가정보: KIS YTM',
#        '평가정보: FNP YTM', '종목정보: 표면금리', '종목정보: 할인율', '종목정보: 매입수익률',
#        '종목정보: 회계적수익률', '종목정보: 발행일', '종목정보: 만기일', '종목정보: 편입일',
#        '종목정보: 업종구분/보증기관', '종목정보: 발행국가', '종목정보: 보증기관', '종목정보: 베타',
#        '종목정보: 지수가중베타', '종목정보: 듀레이션', '종목정보: 컨벡시티', '종목정보: KBP듀레이션',
# ...

# %%
df = get_preprocessed_menu2205_snapshot(date_ref=None)
market_ks = load_market(market_name='ks')
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
# 2 Files matching the regex 'dataset-bbg-ks_market-' in the bucket 'dataset-bbg' with prefix 'dataset-market/':
# Successfully read file: dataset-market/dataset-bbg-ks_market-at20250219-save20250219.csv
# DataFrame shape: (2611, 4)

# %%
df['자산'].unique()
# Out:
# array(['국내주식', '국내채권', 'REPO 매수', 'REPO', '국내현금', '국내수익증권', '국내수익증권(ETF)',
#        '외화주식', '외화현금성', '외화선물', '외화스왑', '기타', '기타(총계정원장)', '총계정원장', '차입금'],
#       dtype=object)

# %%
grouped_dfs = dict(tuple(df.groupby('자산')))
grouped_dfs
# Out:
# {'REPO':               자산 종목명    종목   원화 보유정보: 수량  원화 보유정보: 매매가능수량  원화 보유정보: 장부가액  \
#  2025-02-19  REPO  소계  35 건  147000000000     147000000000   1.470121e+11
#
#              원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 평가손익  원화 보유정보: 손익률  ...  \
#  2025-02-19  1.470121e+11  1.470000e+11            0.0           0.0  ...
#
#              종목정보: 발행기관  종목정보: 이자지급방법  종목정보: 자산분류  종목정보: 시가총액     자산정보: 순자산  \
#  2025-02-19         NaN           NaN         NaN         0.0  2.568999e+12
#
#                 자산정보: 총자산  자산정보: 기준가격  자산정보: 증감  자산정보: ISIN코드  자산정보: TICKER
#  2025-02-19  2.591705e+12     1080.47      1.43           NaN           NaN
#
#  [1 rows x 78 columns],
#  'REPO 매수':                  자산             종목명            종목  원화 보유정보: 수량  \
#  2025-02-19  REPO 매수  REPO(매수) 56115  KRRP25219001   1000000000
#  2025-02-19  REPO 매수  REPO(매수) 56128  KRRP25219002   1000000000
#  2025-02-19  REPO 매수  REPO(매수) 56137  KRRP25219003   1000000000
# ...

# %%
grouped_dfs['REPO 매수']
# Out:
#                  자산             종목명            종목  원화 보유정보: 수량  \
# 2025-02-19  REPO 매수  REPO(매수) 56115  KRRP25219001   1000000000
# 2025-02-19  REPO 매수  REPO(매수) 56128  KRRP25219002   1000000000
# 2025-02-19  REPO 매수  REPO(매수) 56137  KRRP25219003   1000000000
# 2025-02-19  REPO 매수  REPO(매수) 56120  KRRP25219004   1500000000
# 2025-02-19  REPO 매수  REPO(매수) 56108  KRRP25219005  10000000000
# 2025-02-19  REPO 매수  REPO(매수) 56126  KRRP25219006   7000000000
# 2025-02-19  REPO 매수  REPO(매수) 56104  KRRP25219007   1500000000
# 2025-02-19  REPO 매수  REPO(매수) 56116  KRRP25219008   1000000000
# 2025-02-19  REPO 매수  REPO(매수) 56129  KRRP25219009   3000000000
# 2025-02-19  REPO 매수  REPO(매수) 56121  KRRP25219010   1000000000
# 2025-02-19  REPO 매수  REPO(매수) 56109  KRRP25219011  10000000000
# 2025-02-19  REPO 매수  REPO(매수) 56119  KRRP25219012   4000000000
# 2025-02-19  REPO 매수  REPO(매수) 56127  KRRP25219013  24500000000
# 2025-02-19  REPO 매수  REPO(매수) 56105  KRRP25219014   5000000000
# ...

# %%
tuple(df.groupby('자산'))
# Out:
# (('REPO',
#                 자산 종목명    종목   원화 보유정보: 수량  원화 보유정보: 매매가능수량  원화 보유정보: 장부가액  \
#   2025-02-19  REPO  소계  35 건  147000000000     147000000000   1.470121e+11
#
#               원화 보유정보: 평가액  원화 보유정보: 취득액  원화 보유정보: 평가손익  원화 보유정보: 손익률  ...  \
#   2025-02-19  1.470121e+11  1.470000e+11            0.0           0.0  ...
#
#               종목정보: 발행기관  종목정보: 이자지급방법  종목정보: 자산분류  종목정보: 시가총액     자산정보: 순자산  \
#   2025-02-19         NaN           NaN         NaN         0.0  2.568999e+12
#
#                  자산정보: 총자산  자산정보: 기준가격  자산정보: 증감  자산정보: ISIN코드  자산정보: TICKER
#   2025-02-19  2.591705e+12     1080.47      1.43           NaN           NaN
#
#   [1 rows x 78 columns]),
#  ('REPO 매수',
#                    자산             종목명            종목  원화 보유정보: 수량  \
#   2025-02-19  REPO 매수  REPO(매수) 56115  KRRP25219001   1000000000
#   2025-02-19  REPO 매수  REPO(매수) 56128  KRRP25219002   1000000000
#   2025-02-19  REPO 매수  REPO(매수) 56137  KRRP25219003   1000000000
# ...

# %%
grouped_dfs['국내주식']
# Out:
#               자산                     종목명            종목  원화 보유정보: 수량  \
# 2025-02-19  국내주식                    삼양식품  KR7003230000          104
# 2025-02-19  국내주식                     오뚜기  KR7007310006         3417
# 2025-02-19  국내주식                    KT&G  KR7033780008         6238
# 2025-02-19  국내주식                     삼양사  KR7145990008        96133
# 2025-02-19  국내주식                     오리온  KR7271560005      1018091
# ...          ...                     ...           ...          ...
# 2025-02-19  국내주식  에버베스트헬리오스파워PEF(241211)  KRZX73006BC8    730412109
# 2025-02-19  국내주식         홍덕산업 보통주 241018  KRNK48920007        78193
# 2025-02-19  국내주식   와디즈 1우선주 241126 (001)  KRBWDGXX0CPS        93453
# 2025-02-19  국내주식               차바이오텍3우선주  KR708566K01W        57623
# 2025-02-19  국내주식                      소계         217 건    783263491
#
#             원화 보유정보: 매매가능수량  원화 보유정보: 장부가액  원화 보유정보: 평가액  원화 보유정보: 취득액  \
# 2025-02-19              104   8.245835e+07  9.214400e+07  8.245835e+07
# ...

# %%
get_df_stock_snapshot()
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
#        자산                     종목명            종목  원화 보유정보: 수량  원화 보유정보: 매매가능수량  \
# 0    국내주식                    삼양식품  KR7003230000          104              104
# 1    국내주식                     오뚜기  KR7007310006         3417             3417
# 2    국내주식                    KT&G  KR7033780008         6238             6238
# 3    국내주식                     삼양사  KR7145990008        96133            96133
# 4    국내주식                     오리온  KR7271560005      1018091          1018091
# ..    ...                     ...           ...          ...              ...
# 213  국내주식  에버베스트헬리오스파워PEF(241211)  KRZX73006BC8    730412109        730412109
# 214  국내주식         홍덕산업 보통주 241018  KRNK48920007        78193            78193
# ...

# %%
get_df_bond_snapshot()
# Out:
# 1729 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250219-save20250220.csv
# DataFrame shape: (520, 78)
#       자산                     종목명            종목   원화 보유정보: 수량  원화 보유정보: 매매가능수량  \
# 0   국내채권    국고채권03000-2909(24-7)  KR103501GE98    1000000000       1000000000
# 1   국내채권    국고채권03375-2503(23-3)  KR103503GD30   10000000000      10000000000
# 2   국내채권    국고채권02875-2609(24-9)  KR103503GE96    2000000000       2000000000
# 3   국내채권  농업금융채권(은행)2023-03이2Y-C  KR381003GD37   10000000000      10000000000
# 4   국내채권            한국전력공사채권1381  KR350105GD47   10000000000      10000000000
# ..   ...                     ...           ...           ...              ...
# 71  국내채권            화이트비버 전자단기사채  KR9F20742002     700000000        700000000
# 72  국내채권            화이트비버 전자단기사채  KR9F20742003     300000000        300000000
# ...

# %%
2.568999e+12/1e8
# Out:
# 25689.99

# %%
m = Menu2205(fund_code='100060', date_ref='20250217')
m
# Out:
# 1 Files matching the regex 'menu2205-code100060-at20250217' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code100060-at20250217-save20250218.csv
# DataFrame shape: (99, 78)

# %%
m.num_shares
# Out:
# [{'종목명': '삼양사', '원화 보유정보: 수량': 6458},
#  {'종목명': '오리온', '원화 보유정보: 수량': 66000},
#  {'종목명': '넥센타이어', '원화 보유정보: 수량': 6732},
#  {'종목명': '한국타이어앤테크놀로지', '원화 보유정보: 수량': 42792},
#  {'종목명': '대웅', '원화 보유정보: 수량': 10989},
#  {'종목명': 'SK하이닉스', '원화 보유정보: 수량': 3298},
#  {'종목명': '삼성전자', '원화 보유정보: 수량': 27000},
#  {'종목명': 'DN오토모티브', '원화 보유정보: 수량': 123820},
#  {'종목명': '삼성물산', '원화 보유정보: 수량': 3140},
#  {'종목명': 'DL이앤씨', '원화 보유정보: 수량': 12669},
#  {'종목명': 'KSS해운', '원화 보유정보: 수량': 54993},
#  {'종목명': 'KT', '원화 보유정보: 수량': 28799},
#  {'종목명': '세아제강지주', '원화 보유정보: 수량': 5260},
#  {'종목명': '동원산업', '원화 보유정보: 수량': 15802},
#  {'종목명': 'LS', '원화 보유정보: 수량': 3186},
#  {'종목명': '한국금융지주', '원화 보유정보: 수량': 24000},
#  {'종목명': 'GS', '원화 보유정보: 수량': 7706},
#  {'종목명': '하나금융지주', '원화 보유정보: 수량': 7411},
#  {'종목명': '메리츠금융지주', '원화 보유정보: 수량': 1063},
#  {'종목명': 'BNK금융지주', '원화 보유정보: 수량': 232062},
#  {'종목명': 'HD현대', '원화 보유정보: 수량': 900},
#  {'종목명': '우리금융지주', '원화 보유정보: 수량': 273984},
#  {'종목명': '키움증권', '원화 보유정보: 수량': 531},
# ...

# %%
force_int(6458.0)
# Out:
# 6458

# %%
m.get_stock()
# Out:
#               자산          종목명            종목  원화 보유정보: 수량  원화 보유정보: 매매가능수량  \
# 2025-02-17  국내주식          삼양사  KR7145990008         6458             6458
# 2025-02-17  국내주식          오리온  KR7271560005        66000            66000
# 2025-02-17  국내주식        넥센타이어  KR7002350007         6732             6732
# 2025-02-17  국내주식  한국타이어앤테크놀로지  KR7161390000        42792            42792
# 2025-02-17  국내주식           대웅  KR7003090008        10989            10989
# 2025-02-17  국내주식       SK하이닉스  KR7000660001         3298             3298
# 2025-02-17  국내주식         삼성전자  KR7005930003        27000            27000
# 2025-02-17  국내주식      DN오토모티브  KR7007340003       123820           123820
# 2025-02-17  국내주식         삼성물산  KR7028260008         3140             3140
# 2025-02-17  국내주식        DL이앤씨  KR7375500006        12669            12669
# 2025-02-17  국내주식        KSS해운  KR7044450005        54993            54993
# 2025-02-17  국내주식           KT  KR7030200000        28799            28799
# ...

# %%
df=load_menu2205_snapshot(date_ref='20250217')
# Out:
# 1 Files matching the regex 'menu2205-code000000-at20250217' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250217-save20250218.csv
# DataFrame shape: (513, 78)

# %%
preprocess_raw_menu2205(df)
# Out:
#                    자산                         종목명            종목  원화 보유정보: 수량  \
# 2025-02-17       국내주식                        삼양식품  KR7003230000          104
# 2025-02-17       국내주식                         오뚜기  KR7007310006         3417
# 2025-02-17       국내주식                        KT&G  KR7033780008         6238
# 2025-02-17       국내주식                         삼양사  KR7145990008        96133
# 2025-02-17       국내주식                         오리온  KR7271560005      1025814
# ...               ...                         ...           ...          ...
# 2025-02-17  기타(총계정원장)                   선납원천세(지방)       1790200            0
# 2025-02-17      총계정원장                          소계           3 건            0
# 2025-02-17        차입금          신용대출20250311(KB증권)  KRMN24121101   3000000000
# 2025-02-17        차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001   1700000000
# 2025-02-17        차입금                          소계           2 건   4700000000
#
# ...

# %%
df = load_menu2205(fund_code='100060', date_ref='20250217')
df
# Out:
# 1 Files matching the regex 'menu2205-code100060-at20250217' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code100060-at20250217-save20250218.csv
# DataFrame shape: (99, 78)
#            Unnamed: 1     Unnamed: 2    Unnamed: 3        원화 보유정보  \
# Unnamed: 0
# 일자                 자산            종목명            종목             수량
# 2025-02-17       국내주식            삼양사  KR7145990008          6,458
# 2025-02-17       국내주식            오리온  KR7271560005         66,000
# 2025-02-17       국내주식          넥센타이어  KR7002350007          6,732
# 2025-02-17       국내주식    한국타이어앤테크놀로지  KR7161390000         42,792
# ...               ...            ...           ...            ...
# 2025-02-17       외화스왑             소계          34 건  3,116,431,271
# 2025-02-17         기타  주식(ETF)매수미지급금           NaN              0
# 2025-02-17         기타         기타미수입금           NaN              0
# ...

# %%
preprocess_raw_menu2205(df)
# Out:
#               자산            종목명            종목  원화 보유정보: 수량  원화 보유정보: 매매가능수량  \
# 2025-02-17  국내주식            삼양사  KR7145990008         6458             6458
# 2025-02-17  국내주식            오리온  KR7271560005        66000            66000
# 2025-02-17  국내주식          넥센타이어  KR7002350007         6732             6732
# 2025-02-17  국내주식    한국타이어앤테크놀로지  KR7161390000        42792            42792
# 2025-02-17  국내주식             대웅  KR7003090008        10989            10989
# ...          ...            ...           ...          ...              ...
# 2025-02-17  외화스왑             소계          34 건   3116431271       3116431271
# 2025-02-17    기타  주식(ETF)매수미지급금           NaN            0                0
# 2025-02-17    기타         기타미수입금           NaN            0                0
# 2025-02-17    기타     미수(ETF)배당금           NaN            0                0
# 2025-02-17    기타             소계           3 건            0                0
#
# ...

# %%
df = get_preprocessed_menu2205_snapshot(date_ref=None)
df
# Out:
# 1727 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250217-save20250218.csv
# DataFrame shape: (513, 78)
#                    자산                         종목명            종목   원화 보유정보: 수량  \
# 2025-02-17       국내주식                        삼양식품  KR7003230000  1.040000e+02
# 2025-02-17       국내주식                         오뚜기  KR7007310006  3.417000e+03
# 2025-02-17       국내주식                        KT&G  KR7033780008  6.238000e+03
# 2025-02-17       국내주식                         삼양사  KR7145990008  9.613300e+04
# 2025-02-17       국내주식                         오리온  KR7271560005  1.025814e+06
# ...               ...                         ...           ...           ...
# 2025-02-17  기타(총계정원장)                   선납원천세(지방)       1790200  0.000000e+00
# 2025-02-17      총계정원장                          소계           3 건  0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['자산', '종목명', '종목', '원화 보유정보: 수량', '원화 보유정보: 매매가능수량', '원화 보유정보: 장부가액',
#        '원화 보유정보: 평가액', '원화 보유정보: 취득액', '원화 보유정보: 평가손익', '원화 보유정보: 손익률',
#        '원화 보유정보: 취득단가', '원화 보유정보: 미수이자', '원화 보유정보: 선급비용', '원화 보유정보: 상환손익',
#        '외화 보유정보: 외화취득액', '외화 보유정보: 외화평가액', '외화 보유정보: 손익률', '외화 보유정보: 취득단가',
#        '비중: 주식/채권', '비중: 자산대비', '비중: 시장대비', '비중: 시장비중', '대여정보: 대용/담보수량',
#        '대여정보: 대여수량', '대여정보: 대용비율', '대여정보: 대여비율', '평가정보: 종가', '평가정보: 증감',
#        '평가정보: 시가수익률', '평가정보: 증감', '평가정보: 3사평균', '평가정보: 4사평균', '평가정보: KBP가격',
#        '평가정보: NICE가격', '평가정보: KIS가격', '평가정보: FNP가격', '평가정보: 3사평균YTM',
#        '평가정보: 4사평균YTM', '평가정보: KBP YTM', '평가정보: NICE YTM', '평가정보: KIS YTM',
#        '평가정보: FNP YTM', '종목정보: 표면금리', '종목정보: 할인율', '종목정보: 매입수익률',
#        '종목정보: 회계적수익률', '종목정보: 발행일', '종목정보: 만기일', '종목정보: 편입일',
#        '종목정보: 업종구분/보증기관', '종목정보: 발행국가', '종목정보: 보증기관', '종목정보: 베타',
#        '종목정보: 지수가중베타', '종목정보: 듀레이션', '종목정보: 컨벡시티', '종목정보: KBP듀레이션',
# ...

# %%
df.index.name = None
df
# Out:
#                    자산                         종목명            종목  \
# 일자                 자산                         종목명            종목
# 2025-02-17       국내주식                        삼양식품  KR7003230000
# 2025-02-17       국내주식                         오뚜기  KR7007310006
# 2025-02-17       국내주식                        KT&G  KR7033780008
# 2025-02-17       국내주식                         삼양사  KR7145990008
# ...               ...                         ...           ...
# 2025-02-17  기타(총계정원장)                   선납원천세(지방)       1790200
# 2025-02-17      총계정원장                          소계           3 건
# 2025-02-17        차입금          신용대출20250311(KB증권)  KRMN24121101
# 2025-02-17        차입금  신용대출20250321(한국투자증권(PB고유))  KRMN24122001
# 2025-02-17        차입금                          소계           2 건
#
#               원화 보유정보: 수량 원화 보유정보: 매매가능수량  원화 보유정보: 장부가액   원화 보유정보: 평가액  \
# 일자                     수량          매매가능수량           장부가액            평가액
# ...

# %%
menu2205 = load_menu2205(fund_code='100004', date_ref='2025-02-17')
menu2205
# Out:
# 1 Files matching the regex 'menu2205-code100004-at20250217' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code100004-at20250217-save20250218.csv
# DataFrame shape: (51, 78)
#            Unnamed: 1       Unnamed: 2    Unnamed: 3         원화 보유정보  \
# Unnamed: 0
# 일자                 자산              종목명            종목              수량
# 2025-02-17       국내주식              오뚜기  KR7007310006             743
# 2025-02-17       국내주식              삼양사  KR7145990008           2,090
# 2025-02-17       국내주식              오리온  KR7271560005         174,604
# 2025-02-17       국내주식            넥센타이어  KR7002350007          36,311
# 2025-02-17       국내주식      한국타이어앤테크놀로지  KR7161390000         139,769
# 2025-02-17       국내주식           JW중외제약  KR7001060003           5,000
# 2025-02-17       국내주식               대웅  KR7003090008          27,781
# 2025-02-17       국내주식           SK하이닉스  KR7000660001           6,921
# ...

# %%
get_df_preprocessed_column_menu2205(menu2205)
# Out:
#        col1    col2              col
# 0                자산               자산
# 1               종목명              종목명
# 2                종목               종목
# 3   원화 보유정보      수량      원화 보유정보: 수량
# 4   원화 보유정보  매매가능수량  원화 보유정보: 매매가능수량
# ..      ...     ...              ...
# 73     자산정보     총자산        자산정보: 총자산
# 74     자산정보    기준가격       자산정보: 기준가격
# 75     자산정보      증감         자산정보: 증감
# 76     자산정보  ISIN코드     자산정보: ISIN코드
# 77     자산정보  TICKER     자산정보: TICKER
#
# [78 rows x 3 columns]

# %%
menu2205 = load_menu2205(fund_code='100004', date_ref='2025-02-17')
menu2205
# Out:
# 1 Files matching the regex 'menu2205-code100004-at20250217' in the bucket 'dataset-system' with prefix 'dataset-menu2205/':
# Successfully read file: dataset-menu2205/menu2205-code100004-at20250217-save20250218.csv
# DataFrame shape: (51, 78)
#            Unnamed: 1       Unnamed: 2    Unnamed: 3         원화 보유정보  \
# Unnamed: 0
# 일자                 자산              종목명            종목              수량
# 2025-02-17       국내주식              오뚜기  KR7007310006             743
# 2025-02-17       국내주식              삼양사  KR7145990008           2,090
# 2025-02-17       국내주식              오리온  KR7271560005         174,604
# 2025-02-17       국내주식            넥센타이어  KR7002350007          36,311
# 2025-02-17       국내주식      한국타이어앤테크놀로지  KR7161390000         139,769
# 2025-02-17       국내주식           JW중외제약  KR7001060003           5,000
# 2025-02-17       국내주식               대웅  KR7003090008          27,781
# 2025-02-17       국내주식           SK하이닉스  KR7000660001           6,921
# ...

# %%
menu2205.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', '원화 보유정보', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', '외화 보유정보',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', '비중', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', '대여정보', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', '평가정보', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', '종목정보',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51',
#        'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55',
#        'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
# ...

# %%
list(menu2205.iloc[0])
# Out:
# ['자산',
#  '종목명',
#  '종목',
#  '수량',
#  '매매가능수량',
#  '장부가액',
#  '평가액',
#  '취득액',
#  '평가손익',
#  '손익률',
#  '취득단가',
#  '미수이자',
#  '선급비용',
#  '상환손익',
#  '외화취득액',
#  '외화평가액',
#  '손익률',
#  '취득단가',
#  '주식/채권',
#  '자산대비',
#  '시장대비',
#  '시장비중',
#  '대용/담보수량',
#  '대여수량',
#  '대용비율',
#  '대여비율',
#  '종가',
#  '증감',
#  '시가수익률',
#  '증감',
#  '3사평균',
#  '4사평균',
#  'KBP가격',
#  'NICE가격',
#  'KIS가격',
#  'FNP가격',
#  '3사평균YTM',
#  '4사평균YTM',
#  'KBP YTM',
#  'NICE YTM',
#  'KIS YTM',
#  'FNP YTM',
#  '표면금리',
#  '할인율',
#  '매입수익률',
#  '회계적수익률',
#  '발행일',
#  '만기일',
#  '편입일',
#  '업종구분/보증기관',
#  '발행국가',
#  '보증기관',
#  '베타',
#  '지수가중베타',
#  '듀레이션',
#  '컨벡시티',
#  'KBP듀레이션',
#  'KBP컨벡시티',
#  'KIS듀레이션',
#  'KIS컨벡시티',
#  'NICE듀레이션',
#  'NICE컨벡시티',
#  'FNP듀레이션',
#  'FNP컨벡시티',
#  '신용등급',
#  '잔존일수',
#  '표시통화',
#  '옵션행사일',
#  '발행기관',
#  '이자지급방법',
#  '자산분류',
#  '시가총액',
#  '순자산',
#  '총자산',
#  '기준가격',
#  '증감',
#  'ISIN코드',
#  'TICKER']

# %%
import pandas as pd
from pandas import DataFrame
from typing import Dict, List
from financial_dataset_preprocessor.column_preprocessor_basis import (
    COLUMN_NAME_FOR_HEADER_01,
    COLUMN_NAME_FOR_HEADER_02,
    COLUMN_NAME_FOR_RETURN,
    COLUMN_NAME_TOBE_ELIMINATED,
    CHARACTER_TOBE_REPLACED,
    CHARACTER_TOBE_SPLITTED,
)

# %%
def get_data_of_double_columns_in_raw_csv_dataset(df: DataFrame) -> Dict[str, List[str]]:
    return {
        COLUMN_NAME_FOR_HEADER_01: list(df.columns),
        COLUMN_NAME_FOR_HEADER_02: list(df.iloc[0])
    }

# %%
data = get_data_of_double_columns_in_raw_csv_dataset(menu2205)
df = pd.DataFrame(data=data)
df
# Out:
#            col1    col2
# 0    Unnamed: 1      자산
# 1    Unnamed: 2     종목명
# 2    Unnamed: 3      종목
# 3       원화 보유정보      수량
# 4    Unnamed: 5  매매가능수량
# ..          ...     ...
# 73  Unnamed: 74     총자산
# 74  Unnamed: 75    기준가격
# 75  Unnamed: 76      증감
# 76  Unnamed: 77  ISIN코드
# 77  Unnamed: 78  TICKER
#
# [78 rows x 2 columns]

# %%
df['col1'] = df['col1'].apply(lambda x: None if 'Unnamed:' in x else x).ffill().fillna('')
df['col'] = df.apply(lambda x: f"{x['col1']}: {x['col2']}" if x['col1']!='' else x['col2'], axis=1)
df
# Out:
#        col1    col2              col
# 0                자산               자산
# 1               종목명              종목명
# 2                종목               종목
# 3   원화 보유정보      수량      원화 보유정보: 수량
# 4   원화 보유정보  매매가능수량  원화 보유정보: 매매가능수량
# ..      ...     ...              ...
# 73     자산정보     총자산        자산정보: 총자산
# 74     자산정보    기준가격       자산정보: 기준가격
# 75     자산정보      증감         자산정보: 증감
# 76     자산정보  ISIN코드     자산정보: ISIN코드
# 77     자산정보  TICKER     자산정보: TICKER
#
# [78 rows x 3 columns]

# %%
df
# Out:
# {'col1': ['자산',
#   '종목명',
#   '종목',
#   '수량',
#   '매매가능수량',
#   '장부가액',
#   '평가액',
#   '취득액',
#   '평가손익',
#   '손익률',
#   '취득단가',
#   '미수이자',
#   '선급비용',
#   '상환손익',
#   '외화취득액',
#   '외화평가액',
#   '손익률',
#   '취득단가',
#   '주식/채권',
#   '자산대비',
#   '시장대비',
#   '시장비중',
#   '대용/담보수량',
#   '대여수량',
#   '대용비율',
#   '대여비율',
#   '종가',
#   '증감',
#   '시가수익률',
#   '증감',
#   '3사평균',
#   '4사평균',
#   'KBP가격',
#   'NICE가격',
#   'KIS가격',
#   'FNP가격',
#   '3사평균YTM',
#   '4사평균YTM',
#   'KBP YTM',
#   'NICE YTM',
#   'KIS YTM',
#   'FNP YTM',
#   '표면금리',
#   '할인율',
#   '매입수익률',
#   '회계적수익률',
#   '발행일',
#   '만기일',
#   '편입일',
#   '업종구분/보증기관',
#   '발행국가',
#   '보증기관',
#   '베타',
#   '지수가중베타',
#   '듀레이션',
#   '컨벡시티',
#   'KBP듀레이션',
#   'KBP컨벡시티',
#   'KIS듀레이션',
#   'KIS컨벡시티',
#   'NICE듀레이션',
#   'NICE컨벡시티',
#   'FNP듀레이션',
#   'FNP컨벡시티',
#   '신용등급',
#   '잔존일수',
#   '표시통화',
#   '옵션행사일',
#   '발행기관',
#   '이자지급방법',
#   '자산분류',
#   '시가총액',
#   '순자산',
#   '총자산',
#   '기준가격',
#   '증감',
#   'ISIN코드',
#   'TICKER'],
# ...

# %%
load_menu2205_snapshot(date_ref='2025-02-17')
# Out:
# 1 Files matching the regex 'menu2205-code000000-at20250217' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250217-save20250218.csv
# DataFrame shape: (513, 78)
#            Unnamed: 1                  Unnamed: 2    Unnamed: 3  \
# Unnamed: 0
# 일자                 자산                         종목명            종목
# 2025-02-17       국내주식                        삼양식품  KR7003230000
# 2025-02-17       국내주식                         오뚜기  KR7007310006
# 2025-02-17       국내주식                        KT&G  KR7033780008
# 2025-02-17       국내주식                         삼양사  KR7145990008
# ...               ...                         ...           ...
# 2025-02-17  기타(총계정원장)                   선납원천세(지방)       1790200
# 2025-02-17      총계정원장                          소계           3 건
# 2025-02-17        차입금          신용대출20250311(KB증권)  KRMN24121101
# ...

# %%
get_data_of_columns_menu2205(menu2205)
# Out:
# 1727 Files matching the regex 'menu2205-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2205-snapshot/':
# Successfully read file: dataset-menu2205-snapshot/menu2205-code000000-at20250217-save20250218.csv
# DataFrame shape: (513, 78)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_data_of_columns_menu2205(menu2205)
#
# File ~/dev/module-financial_dataset_preprocessor/financial_dataset_preprocessor/menu2205_preprocessor/menu2205_data_generator.py:6, in get_data_of_columns_menu2205(cols)
#       4 def get_data_of_columns_menu2205(cols):
#       5     menu2205_snapshot = get_preprocessed_menu2205_snapshot()
# ----> 6     data = map_df_to_some_data(menu2205_snapshot, cols)
#       7     return data
#
# ...
