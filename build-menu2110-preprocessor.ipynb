# %%
from financial_dataset_preprocessor import *
from financial_dataset_preprocessor.universal_applications import get_grouped_dfs_of_df
# Out:
# INFO:shining_pebbles:shining_pebbles package initialized

# %%
get_fund_codes_class()
# Out:
# 121 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250219-save20250220.csv
# DataFrame shape: (180, 48)
# ['000006',
#  '00000I',
#  '000014',
#  '000019',
#  '00001I',
#  '000040',
#  '000041',
#  '000042',
#  '000046',
#  '000048',
#  '000050',
#  '000054',
#  '000055',
#  '000057',
#  '000058',
#  '000059',
#  '000060',
#  '000063',
#  '000065',
#  '000066',
#  '000068',
#  '000069',
#  '000070',
#  '000072',
#  '000073',
#  '000077',
#  '000079',
#  '000083',
#  '000084',
#  '000085',
#  '000088',
#  '000089',
#  '000091',
#  '000094',
#  '000096',
#  '000097',
#  '000099',
#  '100002',
#  '100003',
#  '100005',
#  '100006',
#  '100007',
#  '100009',
#  '10000C',
#  '10000F',
#  '100010',
#  '100011',
#  '10001C',
#  '100020',
#  '100021',
#  '100022',
#  '100024',
#  '100025',
#  '10002I',
#  '100031',
#  '100036',
#  '100037',
#  '100039',
# ...

# %%
df = get_preprocessed_menu2110(date_ref='2025-01-31')
df
# Out:
# 1 Files matching the regex 'menu2110-code000000-at20250131' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250131-save20250201.csv
# DataFrame shape: (179, 48)
#                                  펀드명  매니저 국내외구분  펀드구분  펀드분류 모자구분  클래스구분 클래스  \
# 000005             라이프IPO일반사모투자신탁제2호  남두우    국내  투자신탁  주식혼합   일반   운용펀드   -
# 000006     라이프IPO일반사모투자신탁제2호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드   C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  남두우    국내  투자신탁  주식혼합   일반  클래스펀드   I
# 000012          라이프IPO전문투자형사모투자신탁제3호  남두우    국내  투자신탁  주식혼합   일반   운용펀드   -
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드   C
# ...                              ...  ...   ...   ...   ...  ...    ...  ..
# A00011                     한국증권금융 일임  이시우    국내  투자일임   주식형   일반     일반   -
# A00012                 라이프 주식 SJ 제3호  강대권    국내  투자일임   주식형   일반     일반   -
# ...

# %%
df = get_preprocessed_menu2110(date_ref='2025-01-31')
df
# Out:
# 1 Files matching the regex 'menu2110-code000000-at20250131' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250131-save20250201.csv
# DataFrame shape: (179, 48)
#                                  펀드명  매니저 국내외구분  펀드구분  펀드분류 모자구분  클래스구분 클래스  \
# 000005             라이프IPO일반사모투자신탁제2호  남두우    국내  투자신탁  주식혼합   일반   운용펀드   -
# 000006     라이프IPO일반사모투자신탁제2호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드   C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  남두우    국내  투자신탁  주식혼합   일반  클래스펀드   I
# 000012          라이프IPO전문투자형사모투자신탁제3호  남두우    국내  투자신탁  주식혼합   일반   운용펀드   -
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드   C
# ...                              ...  ...   ...   ...   ...  ...    ...  ..
# A00011                     한국증권금융 일임  이시우    국내  투자일임   주식형   일반     일반   -
# A00012                 라이프 주식 SJ 제3호  강대권    국내  투자일임   주식형   일반     일반   -
# ...

# %%
grouped_dfs = get_grouped_dfs_of_df(df=df, col='클래스구분')
grouped_dfs
# Out:
# {'-':                                      펀드명  매니저 국내외구분  펀드구분  펀드분류 모자구분 클래스구분  \
#  100083          라이프Engagement일반사모투자신탁제2호  강대권    국내  투자신탁  혼합자산   일반     -
#  100084       라이프Engagement일반사모투자신탁제2호 1종  강대권    국내  투자신탁  혼합자산   일반     -
#  100085       라이프Engagement일반사모투자신탁제2호 2종  강대권    국내  투자신탁  혼합자산   일반     -
#  100086          라이프 글로벌 고배당 일반사모투자신탁 제1호  강대권    국내  투자신탁  혼합자산   일반     -
#  100087       라이프 글로벌 고배당 일반사모투자신탁 제1호 1종  강대권    국내  투자신탁  혼합자산   일반     -
#  100088       라이프 글로벌 고배당 일반사모투자신탁 제1호 2종  강대권    국내  투자신탁  혼합자산   일반     -
#  100089          라이프Engagement일반사모투자신탁제3호  강대권    국내  투자신탁  혼합자산   일반     -
#  100090       라이프Engagement일반사모투자신탁제3호 1종  강대권    국내  투자신탁  혼합자산   일반     -
#  100091       라이프Engagement일반사모투자신탁제3호 2종  강대권    국내  투자신탁  혼합자산   일반     -
#  100106       라이프 Engagement 일반사모투자신탁 제7호  강대권    국내  투자신탁  혼합자산   일반     -
#  100108    라이프 Engagement 일반사모투자신탁 제7호 2종  강대권    국내  투자신탁  혼합자산   일반     -
# ...

# %%
grouped_dfs.keys()
# Out:
# dict_keys(['-', '운용펀드', '일반', '클래스펀드'])

# %%
data = get_all_mappings_of_df(df)
data
# Out:
# 매니저
# 국내외구분
# 펀드구분
# 펀드분류
# 모자구분
# 클래스구분
# 클래스
# 설정일
# 만기일
# 보관은행
# 사무수탁사
# 결산일
# 보수인출일
# 보수율: 운용
# 보수율: 평가
# 보수율: 판매
# 보수율: 기타
# 보수율: 보관
# 보수율: 위원회
# 보수율: 사무수탁
# 보수율: Total
# 판매수수료: 선후취구분
# 판매수수료: 수수료율
# 공모/사모
# 목표수익률
# 금감원코드
# 펀드표준코드
# 예탁원코드
# 협회코드
# 협회분류코드
# 집합투자분류코드
# 채권편입비
# 주식편입비
# 자본금
# 설립자본금
# NAV
# 성과보수여부
# 판매사
# 수익자
# 펀드평가사
# 만기예정일
# 수수료율
# 적용법
# 법적용일
# 한글펀드명
# 영문펀드명
# 시가평가
# {'매니저': {'000005': '남두우',
#   '000006': '남두우',
#   '00000I': '남두우',
#   '000012': '남두우',
#   '000014': '남두우',
#   '000018': '남두우',
#   '000019': '남두우',
#   '00001I': '남두우',
#   '000038': '남두우',
#   '000039': '남두우',
#   '000040': '남두우',
#   '000041': '남두우',
#   '000042': '남두우',
#   '000043': '남두우',
#   '000045': '이시우',
#   '000046': '이시우',
#   '000048': '이시우',
#   '000050': '이시우',
#   '000051': '남두우',
#   '000052': '이시우',
#   '000053': '이시우',
#   '000054': '이시우',
#   '000055': '이시우',
#   '000056': '이시우',
#   '000057': '이시우',
#   '000058': '이시우',
#   '000059': '이시우',
#   '000060': '이시우',
# ...

# %%
get_preprocessed_menu2110(date_ref='2025-01-31')
# Out:
# 1 Files matching the regex 'menu2110-code000000-at20250131' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250131-save20250201.csv
# DataFrame shape: (179, 48)
#                                  펀드명  매니저 국내외구분  펀드구분  펀드분류 모자구분  클래스구분  클래스  \
# 000005             라이프IPO일반사모투자신탁제2호  남두우    국내  투자신탁  주식혼합   일반   운용펀드  NaN
# 000006     라이프IPO일반사모투자신탁제2호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    I
# 000012          라이프IPO전문투자형사모투자신탁제3호  남두우    국내  투자신탁  주식혼합   일반   운용펀드  NaN
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    C
# ...                              ...  ...   ...   ...   ...  ...    ...  ...
# A00011                     한국증권금융 일임  이시우    국내  투자일임   주식형   일반     일반  NaN
# A00012                 라이프 주식 SJ 제3호  강대권    국내  투자일임   주식형   일반     일반  NaN
# ...

# %%
menu2110 = load_menu_snapshot(menu_code='2110')
get_df_preprocessed_column_menu2110(menu2110)
get_preprocessed_column_names_menu2110(menu2110)
# Out:
# 120 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 48)
# ['펀드',
#  '매니저',
#  '국내외구분',
#  '펀드구분',
#  '펀드분류',
#  '모자구분',
#  '클래스구분',
#  '클래스',
#  '설정일',
#  '만기일',
#  '보관은행',
#  '사무수탁사',
#  '결산일',
#  '보수인출일',
#  '보수율: 운용',
#  '보수율: 평가',
#  '보수율: 판매',
#  '보수율: 기타',
#  '보수율: 보관',
#  '보수율: 위원회',
#  '보수율: 사무수탁',
#  '보수율: Total',
#  '판매수수료: 선후취구분',
#  '판매수수료: 수수료율',
#  '판매수수료: 공모/사모',
#  '판매수수료: 목표수익률',
#  '판매수수료: 금감원코드',
#  '판매수수료: 펀드표준코드',
#  '판매수수료: 예탁원코드',
#  '판매수수료: 협회코드',
#  '판매수수료: 협회분류코드',
#  '판매수수료: 집합투자분류코드',
#  '판매수수료: 채권편입비',
#  '판매수수료: 주식편입비',
#  '판매수수료: 자본금',
#  '판매수수료: 설립자본금',
#  '판매수수료: NAV',
#  '판매수수료: 성과보수여부',
#  '판매수수료: 판매사',
#  '판매수수료: 수익자',
#  '판매수수료: 펀드평가사',
#  '판매수수료: 만기예정일',
#  '판매수수료: 수수료율',
#  '판매수수료: 적용법',
#  '판매수수료: 법적용일',
#  '판매수수료: 한글펀드명',
#  '판매수수료: 영문펀드명',
#  '판매수수료: 시가평가']

# %%
df = get_preprocessed_menu2110()
df['클래스구분'] = df['클래스구분'].fillna('-')
cols_to_keep = ['펀드명', '클래스구분', '클래스']
df = df[cols_to_keep]
df
# Out:
# 120 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 48)
#                                  펀드명  클래스구분  클래스
# 000005             라이프IPO일반사모투자신탁제2호   운용펀드  NaN
# 000006     라이프IPO일반사모투자신탁제2호 Class C  클래스펀드    C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  클래스펀드    I
# 000012          라이프IPO전문투자형사모투자신탁제3호   운용펀드  NaN
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  클래스펀드    C
# ...                              ...    ...  ...
# A00011                     한국증권금융 일임     일반  NaN
# A00012                 라이프 주식 SJ 제3호     일반  NaN
# A00013                   라이프 ESG형 7호     일반  NaN
# A00014                   라이프 ESG형 8호     일반  NaN
# A00015                TMF(라이프사회책임1호)     일반  NaN
#
# [179 rows x 3 columns]

# %%
import pandas as pd

df = get_preprocessed_menu2110()
df['클래스구분'] = df['클래스구분'].fillna('-')
cols_to_keep = ['펀드명', '클래스구분']
df = df[cols_to_keep]

custom_order = ['운용펀드', '-', '일반', '클래스펀드']
df['클래스구분'] = pd.Categorical(df['클래스구분'], 
                           categories=custom_order, 
                           ordered=True)

df_sorted = df.sort_values('클래스구분')
df_sorted
# Out:
# 120 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 48)
#                                        펀드명  클래스구분
# 000005                   라이프IPO일반사모투자신탁제2호   운용펀드
# 000076             라이프IPO하이일드알파일반사모투자신탁제1호   운용펀드
# 000082             라이프 IPO코스닥벤처일반사모투자신탁제9호   운용펀드
# 000087  라이프 Growth Engagement 일반사모투자신탁 제2호   운용펀드
# 000090             라이프IPO코스닥벤처일반사모투자신탁제10호   운용펀드
# ...                                    ...    ...
# 10001C      라이프한국기업ESG향상일반사모투자신탁제2호Class C  클래스펀드
# 100011   라이프한국기업ESG향상일반사모투자신탁제2호 Class C-S  클래스펀드
# 100010   라이프한국기업ESG향상일반사모투자신탁제2호 Class C-I  클래스펀드
# 100076      라이프Forest일반사모투자신탁제1호 Class C-S  클래스펀드
# 000042      라이프IPO코스닥벤처일반사모투자신탁제4호 Class S  클래스펀드
#
# [179 rows x 2 columns]

# %%
df['클래스구분'].unique()
# Out:
# array(['운용펀드', '클래스펀드', '일반', nan], dtype=object)

# %%
get_df_fund_type_and_class()
# Out:
# 120 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 48)
#                                  펀드명  펀드분류  클래스구분  클래스
# 000005             라이프IPO일반사모투자신탁제2호  주식혼합   운용펀드  NaN
# 000006     라이프IPO일반사모투자신탁제2호 Class C  주식혼합  클래스펀드    C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  주식혼합  클래스펀드    I
# 000012          라이프IPO전문투자형사모투자신탁제3호  주식혼합   운용펀드  NaN
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  주식혼합  클래스펀드    C
# ...                              ...   ...    ...  ...
# A00011                     한국증권금융 일임   주식형     일반  NaN
# A00012                 라이프 주식 SJ 제3호   주식형     일반  NaN
# A00013                   라이프 ESG형 7호   주식형     일반  NaN
# A00014                   라이프 ESG형 8호   주식형     일반  NaN
# A00015                TMF(라이프사회책임1호)   주식형     일반  NaN
#
# [179 rows x 4 columns]

# %%
get_data_of_columns_menu2110(cols=['펀드코드', '펀드명', '펀드분류', '클래스구분', '클래스'])
# Out:
# 120 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 48)
# [{'펀드코드': '000005',
#   '펀드명': '라이프IPO일반사모투자신탁제2호',
#   '펀드분류': '주식혼합',
#   '클래스구분': '운용펀드',
#   '클래스': ''},
#  {'펀드코드': '000006',
#   '펀드명': '라이프IPO일반사모투자신탁제2호 Class C',
#   '펀드분류': '주식혼합',
#   '클래스구분': '클래스펀드',
#   '클래스': 'C'},
#  {'펀드코드': '00000I',
#   '펀드명': '라이프IPO일반사모투자신탁제2호 Class C-I',
#   '펀드분류': '주식혼합',
#   '클래스구분': '클래스펀드',
#   '클래스': 'I'},
#  {'펀드코드': '000012',
#   '펀드명': '라이프IPO전문투자형사모투자신탁제3호',
#   '펀드분류': '주식혼합',
#   '클래스구분': '운용펀드',
#   '클래스': ''},
#  {'펀드코드': '000014',
#   '펀드명': '라이프IPO전문투자형사모투자신탁제3호 Class C',
#   '펀드분류': '주식혼합',
#   '클래스구분': '클래스펀드',
#   '클래스': 'C'},
#  {'펀드코드': '000018',
#   '펀드명': '라이프SPAC일반사모투자신탁제1호',
#   '펀드분류': '주식혼합',
#   '클래스구분': '운용펀드',
#   '클래스': ''},
#  {'펀드코드': '000019',
# ...

# %%
get_preprocessed_menu3412(date_ref='2025-01-31')
# Out:
# 1 Files matching the regex 'menu3412-code000000-at20250131' in the bucket 'dataset-system' with prefix 'dataset-menu3412/':
# Successfully read file: dataset-menu3412/menu3412-code000000-at20250131-save20250201.csv
# DataFrame shape: (179, 36)
#                                  펀드명         설정일  매니저        시작일자        종료일자  \
# 펀드
# 000005             라이프IPO일반사모투자신탁제2호  2020-08-26  남두우  2020-08-26  2999-12-31
# 000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  남두우  2020-08-26  2999-12-31
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  2024-06-27  남두우  2024-06-27  2999-12-31
# 000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  남두우  2021-02-03  2999-12-31
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  남두우  2021-02-03  2999-12-31
# ...                              ...         ...  ...         ...         ...
# A00011                     한국증권금융 일임  2024-04-24  이시우  2024-04-24  2025-03-31
# A00012                 라이프 주식 SJ 제3호  2024-06-07  강대권  2024-06-07  2999-12-31
# ...

# %%
get_preprocessed_menu3412_nonan(date_ref='2025-01-31')
# Out:
# 1 Files matching the regex 'menu3412-code000000-at20250131' in the bucket 'dataset-system' with prefix 'dataset-menu3412/':
# Successfully read file: dataset-menu3412/menu3412-code000000-at20250131-save20250201.csv
# DataFrame shape: (179, 36)
#                                  펀드명         설정일  매니저        시작일자        종료일자  \
# 펀드
# 000005             라이프IPO일반사모투자신탁제2호  2020-08-26  남두우  2020-08-26  2999-12-31
# 000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  남두우  2020-08-26  2999-12-31
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  2024-06-27  남두우  2024-06-27  2999-12-31
# 000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  남두우  2021-02-03  2999-12-31
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  남두우  2021-02-03  2999-12-31
# ...                              ...         ...  ...         ...         ...
# A00011                     한국증권금융 일임  2024-04-24  이시우  2024-04-24  2025-03-31
# A00012                 라이프 주식 SJ 제3호  2024-06-07  강대권  2024-06-07  2999-12-31
# ...

# %%
menu3412 =load_menu_snapshot('3412')
menu3412
# Out:
# 126 Files matching the regex 'menu3412-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3412/':
# Successfully read file: dataset-menu3412/menu3412-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 36)
#                                  펀드명         설정일  매니저        시작일자        종료일자  \
# 펀드
# 000005             라이프IPO일반사모투자신탁제2호  2020-08-26  남두우  2020-08-26  2999-12-31
# 000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  남두우  2020-08-26  2999-12-31
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  2024-06-27  남두우  2024-06-27  2999-12-31
# 000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  남두우  2021-02-03  2999-12-31
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  남두우  2021-02-03  2999-12-31
# ...                              ...         ...  ...         ...         ...
# A00012                 라이프 주식 SJ 제3호  2024-06-07  강대권  2024-06-07  2999-12-31
# A00013                   라이프 ESG형 7호  2024-11-07  강대권  2024-11-07  2999-12-31
# ...

# %%
def determine_col_name(row):
    if row['col3'] == '기준':
        return f"{row['bm_label']}: {row['col3']}"
    if row['col4'] == '비율':
        return f"{row['bm_label']}: {row['col4']}"
    if row['col5'] == '환율적용':
        return f"{row['bm_label']}: {row['col5']}"
    if row['bm_label'] == None:
        return row['col1']

# %%
menu3412 =load_menu_snapshot('3412')

def determine_col_name(row):
    if row['base'] == '기준':
        return f"{row['bm_label']}: {row['base']}"
    if row['ratio'] == '비율':
        return f"{row['bm_label']}: {row['ratio']}"
    if row['fx'] == '환율적용':
        return f"{row['bm_label']}: {row['fx']}"
    if row['bm_label'] == None:
        return row['col1']

import pandas as pd
def get_df_preprocessed_column_menu3412(menu3412):
    df = pd.DataFrame({'col1': list(menu3412.columns)})
    df['bm_index'] = df['col1'].apply(lambda x: f"{x.replace('BM기준구분', '')}" if 'BM기준구분' in x else None)
    df['bm_label'] = df['col1'].apply(lambda x: f"{x.split('기준구분')[0]}" if 'BM기준구분' in x else None)
    df['base'] = df['col1'].apply(lambda x: f"기준" if 'BM기준구분' in x else None)
    df['ratio'] = df['col1'].apply(lambda x: f"비율" if 'BM비율' in x else None)
    df['fx'] = df['col1'].apply(lambda x: f"환율적용" if '환율적용' in x else None)
    df['bm_label'] = df.apply(lambda x: f"{x['bm_label']}{x['bm_index']}" if x['bm_index']!=None else None, axis=1).ffill()
    df['col'] = df.apply(lambda x: determine_col_name(x), axis=1)
    return df
# Out:
# 126 Files matching the regex 'menu3412-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3412/':
# Successfully read file: dataset-menu3412/menu3412-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 36)
#         col1 bm_index bm_label  base ratio    fx         col
# 0        펀드명     None     None  None  None  None         펀드명
# 1        설정일     None     None  None  None  None         설정일
# 2        매니저     None     None  None  None  None         매니저
# 3       시작일자     None     None  None  None  None        시작일자
# 4       종료일자     None     None  None  None  None        종료일자
# 5      수익률구분     None     None  None  None  None       수익률구분
# 6    BM기준구분1        1      BM1    기준  None  None     BM1: 기준
# 7      BM비율1     None      BM1  None    비율  None     BM1: 비율
# 8       환율적용     None      BM1  None  None  환율적용   BM1: 환율적용
# 9    BM기준구분2        2      BM2    기준  None  None     BM2: 기준
# 10     BM비율2     None      BM2  None    비율  None     BM2: 비율
# ...

# %%
list(menu3412.columns)
# Out:
# ['펀드명',
#  '설정일',
#  '매니저',
#  '시작일자',
#  '종료일자',
#  '수익률구분',
#  'BM기준구분1',
#  'BM비율1',
#  '환율적용',
#  'BM기준구분2',
#  'BM비율2',
#  '환율적용.1',
#  'BM기준구분3',
#  'BM비율3',
#  '환율적용.2',
#  'BM기준구분4',
#  'BM비율4',
#  '환율적용.3',
#  'BM기준구분5',
#  'BM비율5',
#  '환율적용.4',
#  'BM기준구분6',
#  'BM비율6',
#  '환율적용.5',
#  'BM기준구분7',
#  'BM비율7',
#  '환율적용.6',
#  'BM기준구분8',
#  'BM비율8',
#  '환율적용.7',
#  'BM기준구분9',
#  'BM비율9',
#  '환율적용.8',
#  'BM기준구분10',
#  'BM비율10',
#  '환율적용.9']

# %%
def get_column_name(col_name: str) -> str:
    if 'BM기준구분' in col_name:
        bm_base = col_name.split('기준구분')[0]
        bm_index = col_name.replace('BM기준구분', '')
        return f"{bm_base}{bm_index}: 기준"
    elif 'BM비율' in col_name:
        return f"{col_name.replace('BM비율', '')}: 비율"
    elif '환율적용' in col_name:
        return f"{col_name.replace('환율적용', '')}: 환율적용"
    return col_name

# 사용
df = pd.DataFrame({'col1': list(menu3412.columns)})
df['col'] = df['col1'].apply(get_column_name)
df
# Out:
#         col1       col
# 0        펀드명       펀드명
# 1        설정일       설정일
# 2        매니저       매니저
# 3       시작일자      시작일자
# 4       종료일자      종료일자
# 5      수익률구분     수익률구분
# 6    BM기준구분1   BM1: 기준
# 7      BM비율1     1: 비율
# 8       환율적용    : 환율적용
# 9    BM기준구분2   BM2: 기준
# 10     BM비율2     2: 비율
# 11    환율적용.1  .1: 환율적용
# 12   BM기준구분3   BM3: 기준
# 13     BM비율3     3: 비율
# 14    환율적용.2  .2: 환율적용
# 15   BM기준구분4   BM4: 기준
# 16     BM비율4     4: 비율
# 17    환율적용.3  .3: 환율적용
# 18   BM기준구분5   BM5: 기준
# 19     BM비율5     5: 비율
# 20    환율적용.4  .4: 환율적용
# 21   BM기준구분6   BM6: 기준
# 22     BM비율6     6: 비율
# 23    환율적용.5  .5: 환율적용
# 24   BM기준구분7   BM7: 기준
# 25     BM비율7     7: 비율
# 26    환율적용.6  .6: 환율적용
# 27   BM기준구분8   BM8: 기준
# 28     BM비율8     8: 비율
# 29    환율적용.7  .7: 환율적용
# 30   BM기준구분9   BM9: 기준
# 31     BM비율9     9: 비율
# 32    환율적용.8  .8: 환율적용
# 33  BM기준구분10  BM10: 기준
# 34    BM비율10    10: 비율
# 35    환율적용.9  .9: 환율적용

# %%
menu2110 = load_menu_snapshot('2110')
menu2110
# Out:
# 120 Files matching the regex 'menu2110-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250218-save20250219.csv
# DataFrame shape: (180, 48)
#                             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# Unnamed: 0
# 펀드명                                 펀드        매니저      국내외구분       펀드구분
# 라이프IPO일반사모투자신탁제2호               000005        남두우         국내       투자신탁
# 라이프IPO일반사모투자신탁제2호 Class C       000006        남두우         국내       투자신탁
# 라이프IPO일반사모투자신탁제2호 Class C-I     00000I        남두우         국내       투자신탁
# 라이프IPO전문투자형사모투자신탁제3호            000012        남두우         국내       투자신탁
# ...                                ...        ...        ...        ...
# 한국증권금융 일임                       A00011        이시우         국내       투자일임
# 라이프 주식 SJ 제3호                   A00012        강대권         국내       투자일임
# 라이프 ESG형 7호                     A00013        강대권         국내       투자일임
# ...

# %%
df = get_preprocessed_menu2110(date_ref='2025-01-31')
df
# Out:
# 1 Files matching the regex 'menu2110-code000000-at20250131' in the bucket 'dataset-system' with prefix 'dataset-menu2110/':
# Successfully read file: dataset-menu2110/menu2110-code000000-at20250131-save20250201.csv
# DataFrame shape: (179, 48)
#                                  펀드명  매니저 국내외구분  펀드구분  펀드분류 모자구분  클래스구분  클래스  \
# 000005             라이프IPO일반사모투자신탁제2호  남두우    국내  투자신탁  주식혼합   일반   운용펀드  NaN
# 000006     라이프IPO일반사모투자신탁제2호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    I
# 000012          라이프IPO전문투자형사모투자신탁제3호  남두우    국내  투자신탁  주식혼합   일반   운용펀드  NaN
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    C
# ...                              ...  ...   ...   ...   ...  ...    ...  ...
# A00011                     한국증권금융 일임  이시우    국내  투자일임   주식형   일반     일반  NaN
# A00012                 라이프 주식 SJ 제3호  강대권    국내  투자일임   주식형   일반     일반  NaN
# ...

# %%
df.reset_index().set_index('펀드').rename(col)
# Out:
#                                index  매니저 국내외구분  펀드구분  펀드분류 모자구분  클래스구분  클래스  \
# 펀드
# 000005             라이프IPO일반사모투자신탁제2호  남두우    국내  투자신탁  주식혼합   일반   운용펀드  NaN
# 000006     라이프IPO일반사모투자신탁제2호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    C
# 00000I   라이프IPO일반사모투자신탁제2호 Class C-I  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    I
# 000012          라이프IPO전문투자형사모투자신탁제3호  남두우    국내  투자신탁  주식혼합   일반   운용펀드  NaN
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  남두우    국내  투자신탁  주식혼합   일반  클래스펀드    C
# ...                              ...  ...   ...   ...   ...  ...    ...  ...
# A00011                     한국증권금융 일임  이시우    국내  투자일임   주식형   일반     일반  NaN
# A00012                 라이프 주식 SJ 제3호  강대권    국내  투자일임   주식형   일반     일반  NaN
# A00013                   라이프 ESG형 7호  강대권    국내  투자일임   주식형   일반     일반  NaN
# A00014                   라이프 ESG형 8호  강대권    국내  투자일임   주식형   일반     일반  NaN
# A00015                TMF(라이프사회책임1호)  강대권    국내  투자일임   주식형   일반     일반  NaN
#
# ...

# %%
get_df_preprocessed_column_menu2110(menu2110)
# Out:
#      col1      col2              col
# 0    None        펀드               펀드
# 1    None       매니저              매니저
# 2    None     국내외구분            국내외구분
# 3    None      펀드구분             펀드구분
# 4    None      펀드분류             펀드분류
# 5    None      모자구분             모자구분
# 6    None     클래스구분            클래스구분
# 7    None       클래스              클래스
# 8    None       설정일              설정일
# 9    None       만기일              만기일
# 10   None      보관은행             보관은행
# 11   None     사무수탁사            사무수탁사
# 12   None       결산일              결산일
# 13   None     보수인출일            보수인출일
# 14    보수율        운용          보수율: 운용
# 15    보수율        평가          보수율: 평가
# 16    보수율        판매          보수율: 판매
# 17    보수율        기타          보수율: 기타
# 18    보수율        보관          보수율: 보관
# 19    보수율       위원회         보수율: 위원회
# 20    보수율      사무수탁        보수율: 사무수탁
# 21    보수율     Total       보수율: Total
# 22  판매수수료     선후취구분     판매수수료: 선후취구분
# 23  판매수수료      수수료율      판매수수료: 수수료율
# ...
