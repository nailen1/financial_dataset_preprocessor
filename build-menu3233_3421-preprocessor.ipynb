# %%
from financial_dataset_preprocessor import *
# Out:
# INFO:shining_pebbles:shining_pebbles package initialized

# %%
get_preprocessed_menu3421(date_ref=None)
# Out:
# 128 Files matching the regex 'menu3421-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3421/':
# Successfully read file: dataset-menu3421/menu3421-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 156)
#                                  한글명         설정일       다음결산일  \
# 펀드
# 000005             라이프IPO일반사모투자신탁제2호  2020-08-26  2025-08-25
# 000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  2025-08-25
# 000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  2026-02-02
# 000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  2026-02-02
# 000018            라이프SPAC일반사모투자신탁제1호  2021-03-25  2025-03-24
# ...                              ...         ...         ...
# A00011                     한국증권금융 일임  2024-04-24  2025-03-31
# A00012                 라이프 주식 SJ 제3호  2024-06-07  2099-12-31
# A00013                   라이프 ESG형 7호  2024-11-07  2099-12-31
# A00014                   라이프 ESG형 8호  2024-11-08  2099-12-31
# ...

# %%
load_menu_snapshot(menu_code='3421')
# Out:
# 128 Files matching the regex 'menu3421-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3421/':
# Successfully read file: dataset-menu3421/menu3421-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 156)
#          펀드                           한글명         설정일       다음결산일  \
# 순번
# 1    000005             라이프IPO일반사모투자신탁제2호  2020-08-26  2025-08-25
# 2    000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  2025-08-25
# 3    000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  2026-02-02
# 4    000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  2026-02-02
# 5    000018            라이프SPAC일반사모투자신탁제1호  2021-03-25  2025-03-24
# ..      ...                           ...         ...         ...
# 172  A00011                     한국증권금융 일임  2024-04-24  2025-03-31
# 173  A00012                 라이프 주식 SJ 제3호  2024-06-07  2099-12-31
# 174  A00013                   라이프 ESG형 7호  2024-11-07  2099-12-31
# 175  A00014                   라이프 ESG형 8호  2024-11-08  2099-12-31
# ...

# %%
df = get_preprocessed_menu3233(date_ref=None)
df
# Out:
# 126 Files matching the regex 'menu3233-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3233/':
# Successfully read file: dataset-menu3233/menu3233-code000000-at20250219-save20250220.csv
# DataFrame shape: (204, 18)
#                             기준일    펀드코드                           펀드명  \
# 000005-공통            2025-02-19  000005             라이프IPO일반사모투자신탁제2호
# 000006-DB금융투자        2025-02-19  000006     라이프IPO일반사모투자신탁제2호 Class C
# 000012-공통            2025-02-19  000012          라이프IPO전문투자형사모투자신탁제3호
# 000014-DB금융투자        2025-02-19  000014  라이프IPO전문투자형사모투자신탁제3호 Class C
# 000018-공통            2025-02-19  000018            라이프SPAC일반사모투자신탁제1호
# ...                         ...     ...                           ...
# A00011-공통            2025-02-19  A00011                     한국증권금융 일임
# A00012-산림조합중앙회(판매사)  2025-02-19  A00012                 라이프 주식 SJ 제3호
# A00013-대한지방행정공제회     2025-02-19  A00013                   라이프 ESG형 7호
# ...

# %%
df.index = df['펀드코드'] + df['판매사'].str.replace(' ','')
df
# Out:
#                            기준일    펀드코드                           펀드명  \
# 000005공통            2025-02-19  000005             라이프IPO일반사모투자신탁제2호
# 000006DB금융투자        2025-02-19  000006     라이프IPO일반사모투자신탁제2호 Class C
# 000012공통            2025-02-19  000012          라이프IPO전문투자형사모투자신탁제3호
# 000014DB금융투자        2025-02-19  000014  라이프IPO전문투자형사모투자신탁제3호 Class C
# 000018공통            2025-02-19  000018            라이프SPAC일반사모투자신탁제1호
# ...                        ...     ...                           ...
# A00011공통            2025-02-19  A00011                     한국증권금융 일임
# A00012산림조합중앙회(판매사)  2025-02-19  A00012                 라이프 주식 SJ 제3호
# A00013대한지방행정공제회     2025-02-19  A00013                   라이프 ESG형 7호
# A00014대한지방행정공제회     2025-02-19  A00014                   라이프 ESG형 8호
# A00015공통            2025-02-19  A00015                TMF(라이프사회책임1호)
#
#                            설정일   판매사코드           판매사   통화  운용보수  판매보수  수탁보수  \
# ...

# %%
load_menu_snapshot(menu_code='3421')
# Out:
# 128 Files matching the regex 'menu3421-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3421/':
# Successfully read file: dataset-menu3421/menu3421-code000000-at20250219-save20250220.csv
# DataFrame shape: (176, 156)
#          펀드                           한글명         설정일       다음결산일  \
# 순번
# 1    000005             라이프IPO일반사모투자신탁제2호  2020-08-26  2025-08-25
# 2    000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  2025-08-25
# 3    000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  2026-02-02
# 4    000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  2026-02-02
# 5    000018            라이프SPAC일반사모투자신탁제1호  2021-03-25  2025-03-24
# ..      ...                           ...         ...         ...
# 172  A00011                     한국증권금융 일임  2024-04-24  2025-03-31
# 173  A00012                 라이프 주식 SJ 제3호  2024-06-07  2099-12-31
# 174  A00013                   라이프 ESG형 7호  2024-11-07  2099-12-31
# 175  A00014                   라이프 ESG형 8호  2024-11-08  2099-12-31
# ...

# %%
get_preprocessed_menu3421(date_ref=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_preprocessed_menu3421(date_ref=None)
#
# NameError: name 'get_preprocessed_menu3421' is not defined

# %%
menu3233 = load_menu_snapshot(menu_code='3233')
menu3233
# Out:
# 126 Files matching the regex 'menu3233-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3233/':
# Successfully read file: dataset-menu3233/menu3233-code000000-at20250219-save20250220.csv
# DataFrame shape: (204, 18)
#             기준일    펀드코드                           펀드명         설정일   판매사코드  \
# 순번
# 1    2025-02-19  000005             라이프IPO일반사모투자신탁제2호  2020-08-26  000000
# 2    2025-02-19  000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  000031
# 3    2025-02-19  000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  000000
# 4    2025-02-19  000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  000031
# 5    2025-02-19  000018            라이프SPAC일반사모투자신탁제1호  2021-03-25  000000
# ..          ...     ...                           ...         ...     ...
# 200  2025-02-19  A00011                     한국증권금융 일임  2024-04-24  000000
# 201  2025-02-19  A00012                 라이프 주식 SJ 제3호  2024-06-07  KS0014
# ...

# %%
menu3233.columns
# Out:
# Index(['기준일', '펀드코드', '펀드명', '설정일', '판매사코드', '판매사', '통화', '운용보수', '판매보수',
#        '수탁보수', '사무수탁보수', '펀드평가보수', '기타보수(수익자)', '총보수', '설정좌수', '설정금액',
#        '보수계상기준', '적용법'],
#       dtype='object')
